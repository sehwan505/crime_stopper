# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
data = pd.read_json("stream_result.json", lines=True)
data
# Out:
#                 created_at                   id               id_str  \
# 0      2020-08-23 16:23:16  1297434214342651907  1297434214342651904
# 1      2020-08-23 16:23:19  1297434226820669440  1297434226820669440
# 2      2020-08-23 16:23:19  1297434228674539520  1297434228674539520
# 3      2020-08-23 16:23:20  1297434232613085184  1297434232613085184
# 4      2020-08-23 16:23:21  1297434235167338496  1297434235167338496
# ...                    ...                  ...                  ...
# 125404 2020-09-11 22:35:19  1304413212935290883  1304413212935290880
# 125405 2020-09-11 22:35:22  1304413226814246913  1304413226814246912
# 125406 2020-09-11 22:35:24  1304413235399913473  1304413235399913472
# 125407 2020-09-11 22:35:25  1304413236742168578  1304413236742168576
# 125408 2020-09-11 22:35:27  1304413245113954304  1304413245113954304
#
#                                                      text  \
# 0       뢰알...덥의 많아졋다 많아졌다 하지만 인터넷 트위터 공카 말고는 오프라인으로 와닿...
# 1       RT @th1nk_of_u: 알겠어 민혁아 트위터 아이디 뭐냐니깐??? 별거안하고 ...
# 2       RT @Nan_yy28: 야...... 나 트위터 넘 많이 들어온다\n3달 내로 트...
# 3       RT @haj1i: 나도 트위터 처음 시작할때 되게 조신했음... 어느정도엿냐면 퍼...
# 4       RT @Nan_yy28: 야...... 나 트위터 넘 많이 들어온다\n3달 내로 트...
# ...                                                   ...
# 125404  출퇴근이전부인 외로운 20대 직장입니다 ㅠㅠ 편하게대화할수잇는친구원해요문자줘요 라인...
# 125405             운동끝!\n#섹트 #맘눌뎀 https://t.co/IpuRT2njom
# 125406  몰래 클리비비는중 #섹트 #비떱 #에세머 #펨섭 #뚱녀 #뚱녀성애자 #ㅈㅇ  htt...
# 125407           저 와써요!! 놀아줘요 #섹트 https://t.co/ij3mOfO3Lv
# 125408                                       나 일산 인데\n#섹트
#
#                                                    source  truncated  \
# 0       <a href="http://twitter.com/download/iphone" r...      False
# 1       <a href="http://twitter.com/download/android" ...      False
# 2       <a href="http://twitter.com/download/android" ...      False
# 3       <a href="http://twitter.com/download/android" ...      False
# 4       <a href="http://twitter.com/download/android" ...      False
# ...                                                   ...        ...
# 125404  <a href="http://twitter.com/download/iphone" r...       True
# 125405  <a href="http://twitter.com/download/iphone" r...      False
# 125406  <a href="http://twitter.com/download/iphone" r...      False
# 125407  <a href="http://twitter.com/download/android" ...      False
# 125408  <a href="http://twitter.com/download/android" ...      False
#
#         in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                         NaN                        NaN                  NaN
# 1                         NaN                        NaN                  NaN
# 2                         NaN                        NaN                  NaN
# 3                         NaN                        NaN                  NaN
# 4                         NaN                        NaN                  NaN
# ...                       ...                        ...                  ...
# 125404                    NaN                        NaN                  NaN
# 125405                    NaN                        NaN                  NaN
# 125406                    NaN                        NaN                  NaN
# 125407                    NaN                        NaN                  NaN
# 125408                    NaN                        NaN                  NaN
#
#         in_reply_to_user_id_str  ...  \
# 0                           NaN  ...
# 1                           NaN  ...
# 2                           NaN  ...
# 3                           NaN  ...
# 4                           NaN  ...
# ...                         ...  ...
# 125404                      NaN  ...
# 125405                      NaN  ...
# 125406                      NaN  ...
# 125407                      NaN  ...
# 125408                      NaN  ...
#
#                                          retweeted_status  \
# 0                                                     NaN
# 1       {'created_at': 'Sun Aug 23 06:12:58 +0000 2020...
# 2       {'created_at': 'Mon Aug 17 14:32:27 +0000 2020...
# 3       {'created_at': 'Sun Aug 23 05:51:38 +0000 2020...
# 4       {'created_at': 'Mon Aug 17 14:32:27 +0000 2020...
# ...                                                   ...
# 125404                                                NaN
# 125405                                                NaN
# 125406                                                NaN
# 125407                                                NaN
# 125408                                                NaN
#
#                                         extended_entities  possibly_sensitive  \
# 0                                                     NaN                 NaN
# 1                                                     NaN                 NaN
# 2                                                     NaN                 NaN
# 3                                                     NaN                 NaN
# 4                                                     NaN                 NaN
# ...                                                   ...                 ...
# 125404                                                NaN                 0.0
# 125405  {'media': [{'id': 1304413219927109633, 'id_str...                 1.0
# 125406                                                NaN                 0.0
# 125407  {'media': [{'id': 1304413218274553856, 'id_str...                 0.0
# 125408                                                NaN                 NaN
#
#         display_text_range quoted_status_id  quoted_status_id_str  \
# 0                      NaN              NaN                   NaN
# 1                      NaN              NaN                   NaN
# 2                      NaN              NaN                   NaN
# 3                      NaN              NaN                   NaN
# 4                      NaN              NaN                   NaN
# ...                    ...              ...                   ...
# 125404            [0, 140]              NaN                   NaN
# 125405             [0, 13]              NaN                   NaN
# 125406                 NaN              NaN                   NaN
# 125407             [0, 16]              NaN                   NaN
# 125408                 NaN              NaN                   NaN
#
#         quoted_status  quoted_status_permalink  \
# 0                 NaN                      NaN
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# ...               ...                      ...
# 125404            NaN                      NaN
# 125405            NaN                      NaN
# 125406            NaN                      NaN
# 125407            NaN                      NaN
# 125408            NaN                      NaN
#
#                                            extended_tweet  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 125404  {'full_text': '출퇴근이전부인 외로운 20대 직장입니다 ㅠㅠ 편하게대화할...
# 125405                                                NaN
# 125406                                                NaN
# 125407                                                NaN
# 125408                                                NaN
#
#         withheld_in_countries
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 125404                    NaN
# 125405                    NaN
# 125406                    NaN
# 125407                    NaN
# 125408                    NaN
#
# [125409 rows x 37 columns]

# %%
data = data.drop(data.columns[data.isnull().sum()>0], axis=1)

data["user"][0]
# Out:
# {'id': 1278732293830373377,
#  'id_str': '1278732293830373377',
#  'name': '영복이',
#  'screen_name': 'y0ungJA2',
#  'location': None,
#  'url': None,
#  'description': None,
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 97,
#  'friends_count': 95,
#  'listed_count': 1,
#  'favourites_count': 228,
#  'statuses_count': 4630,
#  'created_at': 'Thu Jul 02 16:48:44 +0000 2020',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': '',
#  'profile_background_image_url_https': '',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1286830678168883202/gG1CMnTk_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286830678168883202/gG1CMnTk_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1278732293830373377/1595576495',
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %%
for i in ["screen_name","name","followers_count"]: #user디렉토리에 있는 name,screen_name등을 따로 컬럼으로 만듬
    temp = []
    for j in data["user"]:
        temp.append(j[i])
    data[i] = temp

# %%
temp = [] #엔티티의 hashtags가져옴
for j in data["entities"]:
    temp.append(j["hashtags"])
data["hashtags"] = temp

# %%
twitter_id1 = pd.read_csv("twitter_id.csv")
twitter_id2 = pd.read_csv("twitter_id2.csv")

# %%
twitter_id1["name"].str.find("또또")
# Out:
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 4070   -1
# 4071   -1
# 4072    0
# 4073   -1
# 4074   -1
# Name: name, Length: 4075, dtype: int64

# %%
-twitter_id2["name"].count()
# Out:
# -6430

# %%
#전에 활동했던 사람들이 아직도 활동한는 지 확인

count = 0
for i in twitter_id1["name"]:
    if twitter_id2["name"].str.find(i).sum() > -(twitter_id2["name"].count()):
        print(f"{i}가 중복 됩니다.")
        count += 1
print(count)
# Out:
# Minaaa가 중복 됩니다.
# 폰팅 잘하는 민지가 중복 됩니다.
# 폰팅 잘하는 민지가 중복 됩니다.
# Assa In Inssa가 중복 됩니다.
# 폰팅♥ 전화데이트♥ 폰섹♥ 오빠콜♥ 콜~~가 중복 됩니다.
# Assa In Inssa가 중복 됩니다.
# 동구묭가 중복 됩니다.
# ㅡㅡ가 중복 됩니다.
# 폰팅 성인대화 060-502-3500가 중복 됩니다.
# 폰팅 폰섹 060 501 5600가 중복 됩니다.
# 폰팅 성인대화 060-502-3500가 중복 됩니다.
# 폰팅-폰팅싼곳-폰섹 ☎.060-500-1813♥가 중복 됩니다.
# tatoo.MD가 중복 됩니다.
# 폰팅-폰팅싼곳-폰섹 ☎.060-500-1813♥가 중복 됩니다.
# 멜돔가 중복 됩니다.
# 폰팅-폰팅싼곳-폰섹 ☎.060-500-1813♥가 중복 됩니다.
# 밍가 중복 됩니다.
# 폰팅 성인대화 060-502-3500가 중복 됩니다.
# 폰팅-확실하게싸는곳-폰섹 ♥️060-500-4423♥️가 중복 됩니다.
# 폰팅 지금 바로 할사람~외로운 사람~ 요기서 나랑~가 중복 됩니다.
# 🏩폰섹 자영 C컵 하은샾🏩가 중복 됩니다.
# 음란한 유나가 중복 됩니다.
# 서울18남가 중복 됩니다.
# 폰섹 온풀❤이온가 중복 됩니다.
# 수빈이가 중복 됩니다.
# Ash가 중복 됩니다.
# tatoo.MD가 중복 됩니다.
# 암캐,암퇘지 조련사가 중복 됩니다.
# 준준가 중복 됩니다.
# 암캐,암퇘지 조련사가 중복 됩니다.
# 21주인가 중복 됩니다.
# 새미가 중복 됩니다.
# 혜린가 중복 됩니다.
# 폰팅 죽이는 목소리 역할놀이 할사람가 중복 됩니다.
# 염가 중복 됩니다.
# 하율가 중복 됩니다.
# 야동 야한동영상가 중복 됩니다.
# 판매계가 중복 됩니다.
# 대구경산30가 중복 됩니다.
# ❤폰섹여왕 소민❤가 중복 됩니다.
# ☝️온플 1등 다미☝️가 중복 됩니다.
# 변ㄴ 은지가 중복 됩니다.
# ❤가 중복 됩니다.
# 앙가 중복 됩니다.
# 아영가 중복 됩니다.
# 아잉가 중복 됩니다.
# 수가 중복 됩니다.
# 폰팅폰섹 060-900-0009 좋은여자 착한여자 은꼴대화 폰팅폰섹 언제든지 야하게가 중복 됩니다.
# 야동 성인동영상 포르노 섹트가 중복 됩니다.
# 21주인0가 중복 됩니다.
# 윤이가 중복 됩니다.
# Mm가 중복 됩니다.
# 은아가 중복 됩니다.
# 폰팅폰섹 060-900-0060 폰팅폰섹 예쁜여자 섹시미녀가 중복 됩니다.
# ㅂㄴ가 중복 됩니다.
# 심심해요(게이)🏳️‍🌈가 중복 됩니다.
# 폰팅폰섹 060-909-9799 청순미녀 섹시미녀 대화방가 중복 됩니다.
# ...가 중복 됩니다.
# 주인가 중복 됩니다.
# 야동판매가 중복 됩니다.
# 얼싸가 중복 됩니다.
# 수아가 중복 됩니다.
# 0가 중복 됩니다.
# 17변남가 중복 됩니다.
# 유진가 중복 됩니다.
# 고딩가 중복 됩니다.
# 천제가 중복 됩니다.
# Dreaiq가 중복 됩니다.
# 민경가 중복 됩니다.
# wk가 중복 됩니다.
# df가 중복 됩니다.
# 미스터쓰롯(Mr.Throat)가 중복 됩니다.
# 민지가 중복 됩니다.
# MM가 중복 됩니다.
# 김선미가 중복 됩니다.
# 22남가 중복 됩니다.
# jaywon가 중복 됩니다.
# 𝑁𝑎𝑚𝑒가 중복 됩니다.
# FX모아가 중복 됩니다.
# 月가 중복 됩니다.
# 🌸가 중복 됩니다.
# 05🤔가 중복 됩니다.
# 교미❤가 중복 됩니다.
# Miru가 중복 됩니다.
# 강아지가 중복 됩니다.
# Alex가 중복 됩니다.
# rde가 중복 됩니다.
# ㄴ가 중복 됩니다.
# 888가 중복 됩니다.
# 양영재가 중복 됩니다.
# 까무스가 중복 됩니다.
# 섹스밤19-무료야동 국내야동 한국야동 일본야동 중국야동 서양야동가 중복 됩니다.
# ㅇ가 중복 됩니다.
# 댕댕이가 중복 됩니다.
# 뒷계가 중복 됩니다.
# 폰섹❤정이가 중복 됩니다.
# 여보가 중복 됩니다.
# 🐲가 중복 됩니다.
# ABC가 중복 됩니다.
# d가 중복 됩니다.
# 공주가 중복 됩니다.
# 이재웅가 중복 됩니다.
# 🐽가 중복 됩니다.
# 갓고딩가 중복 됩니다.
# 짹짹이가 중복 됩니다.
# ᴘᴜʀᴘʟᴇ가 중복 됩니다.
# ._.가 중복 됩니다.
# 요롱롱가 중복 됩니다.
# 후루욱가 중복 됩니다.
# 김연디가 중복 됩니다.
# kikikiki가 중복 됩니다.
# 맛집가 중복 됩니다.
# 오형준가 중복 됩니다.
# Cookie가 중복 됩니다.
# 유정가 중복 됩니다.
# 하찌가 중복 됩니다.
# 060폰팅❤민정가 중복 됩니다.
# 장성재🐶가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 청주훈훈남가 중복 됩니다.
# 고영재가 중복 됩니다.
# Soft Grey, 3x, single가 중복 됩니다.
# gggkkkddd가 중복 됩니다.
# deep k가 중복 됩니다.
# 지훈가 중복 됩니다.
# 박준장가 중복 됩니다.
# 𝑨𝒍𝒊가 중복 됩니다.
# 솔가 중복 됩니다.
# 루가 중복 됩니다.
# MD보끈가 중복 됩니다.
# 누엘가 중복 됩니다.
# 💙가 중복 됩니다.
# 맹가 중복 됩니다.
# 🤍가 중복 됩니다.
# 민가 중복 됩니다.
# 김남석가 중복 됩니다.
# 핀돔 루나가 중복 됩니다.
# 이야가 중복 됩니다.
# 구름이가 중복 됩니다.
# 꼬미💜가 중복 됩니다.
# 공가 중복 됩니다.
# 𝑀𝒶 𝒷𝑒𝓁𝓁𝑒가 중복 됩니다.
# 펨돔 솔비👑 (온플후기)가 중복 됩니다.
# ckenx가 중복 됩니다.
# 펨돔 FD솔비👑 온플/영상가 중복 됩니다.
# 김 트 찐가 중복 됩니다.
# 바나브가 중복 됩니다.
# 🎁가 중복 됩니다.
# 예서가 중복 됩니다.
# vieqi가 중복 됩니다.
# DAY가 중복 됩니다.
# ..가 중복 됩니다.
# 운동여신*가 중복 됩니다.
# 모가 중복 됩니다.
# 💋가 중복 됩니다.
# 장미🌹가 중복 됩니다.
# Sd가 중복 됩니다.
# 흐드드드드가 중복 됩니다.
# ღ’ᴗ’ღ가 중복 됩니다.
# 밍👑가 중복 됩니다.
# 핀돔 루나가 중복 됩니다.
# 조이가 중복 됩니다.
# 얌얌굿가 중복 됩니다.
# soso가 중복 됩니다.
# kingseok가 중복 됩니다.
# 심심한 계정가 중복 됩니다.
# 익명가 중복 됩니다.
# hyeon가 중복 됩니다.
# 구름이가 중복 됩니다.
# ◡̈가 중복 됩니다.
# 잼나가 중복 됩니다.
# 06변녀가 중복 됩니다.
# 발정보지다은❤️가 중복 됩니다.
# 🐣가 중복 됩니다.
# 김츄가 중복 됩니다.
# 원가 중복 됩니다.
# 🐕가 중복 됩니다.
# come가 중복 됩니다.
# ㅋ가 중복 됩니다.
# 이이이가 중복 됩니다.
# 현이가 중복 됩니다.
# 🍒가 중복 됩니다.
# 시팔새끼가 중복 됩니다.
# 다나가 중복 됩니다.
# 고영가 중복 됩니다.
# 글쓰는 공허가 중복 됩니다.
# 화화가 중복 됩니다.
# 𝑀𝑜𝑜가 중복 됩니다.
# 공쥬👸가 중복 됩니다.
# 엑엑가 중복 됩니다.
# 란가 중복 됩니다.
# 연가 중복 됩니다.
# 동동가 중복 됩니다.
# 은비가 중복 됩니다.
# 𝑭𝒆𝒃𝒓𝒖𝒂𝒓𝒚가 중복 됩니다.
# Jun가 중복 됩니다.
# 아니야가 중복 됩니다.
# H가 중복 됩니다.
# 응가 중복 됩니다.
# 훈가 중복 됩니다.
# collector가 중복 됩니다.
# 😈가 중복 됩니다.
# 고딩남가 중복 됩니다.
# 캬캬파파가 중복 됩니다.
# H가 중복 됩니다.
# 몸매 운동 과정 기록가 중복 됩니다.
# ㄴ가 중복 됩니다.
# 정해선가 중복 됩니다.
# Yolo__su가 중복 됩니다.
# 암캐 조련사가 중복 됩니다.
# 정가 중복 됩니다.
# 구 르 미 ☁가 중복 됩니다.
# Sam가 중복 됩니다.
# 후후가 중복 됩니다.
# 세은가 중복 됩니다.
# 조련사가 중복 됩니다.
# ❤️가 중복 됩니다.
# ebwown가 중복 됩니다.
# 🍬가 중복 됩니다.
# ルル가 중복 됩니다.
# 린가 중복 됩니다.
# A가 중복 됩니다.
# 곽훈호가 중복 됩니다.
# 지인가 중복 됩니다.
# 인천 사는 장난감 🚀 (오프,섹트,섹스,애무,시오후키,플,관전 전용 장난감)가 중복 됩니다.
# 유현가 중복 됩니다.
# 므가 중복 됩니다.
# 제하가 중복 됩니다.
# 🍑가 중복 됩니다.
# 조아가 중복 됩니다.
# 서이가 중복 됩니다.
# LU가 중복 됩니다.
# 𝑝𝑟𝑖𝑛𝑐𝑒𝑠𝑠 👸🏻가 중복 됩니다.
# 기우가 중복 됩니다.
# 루나가 중복 됩니다.
# 💙FDsurin💙가 중복 됩니다.
# 🔥가 중복 됩니다.
# 청월가 중복 됩니다.
# 💮가 중복 됩니다.
# 체리가 중복 됩니다.
# 뚱이가 중복 됩니다.
# 망개❤️가 중복 됩니다.
# 17남가 중복 됩니다.
# 천뭉가 중복 됩니다.
# 민호가 중복 됩니다.
# ☁️가 중복 됩니다.
# 지은가 중복 됩니다.
# 🪐가 중복 됩니다.
# 크라잉울프가 중복 됩니다.
# 애옹가 중복 됩니다.
# 폴짝가 중복 됩니다.
# 은이💕가 중복 됩니다.
# 말랑가 중복 됩니다.
# 재희가 중복 됩니다.
# 𝘔𝘶𝘴𝘦가 중복 됩니다.
# 아헤가오 합성 제작가 중복 됩니다.
# 김용주가 중복 됩니다.
# hgh224339가 중복 됩니다.
# ㅈㅈㅈ가 중복 됩니다.
# 왕자가 중복 됩니다.
# 52🥒가 중복 됩니다.
# just_in_fxxk가 중복 됩니다.
# 김준가 중복 됩니다.
# 🖤가 중복 됩니다.
# sk가 중복 됩니다.
# 𝑪𝒐𝒌𝒆가 중복 됩니다.
# 츄르가 중복 됩니다.
# 바리가 중복 됩니다.
# 김 둥가 중복 됩니다.
# 슬잉가 중복 됩니다.
# VIL가 중복 됩니다.
# 라온가 중복 됩니다.
# 쀼님♥가 중복 됩니다.
# 대구가 중복 됩니다.
# 수은❤폰팅폰섹전화방만남가 중복 됩니다.
# 이다연가 중복 됩니다.
# 흠냐가 중복 됩니다.
# ℝ𝕠𝕤𝕖𝕞𝕒𝕣𝕪가 중복 됩니다.
# 🍎가 중복 됩니다.
# 설명가 중복 됩니다.
# 수빈가 중복 됩니다.
# 紅雅가 중복 됩니다.
# 부산게이가 중복 됩니다.
# 준가 중복 됩니다.
# 먀먛가 중복 됩니다.
# 조영택가 중복 됩니다.
# 정은성가 중복 됩니다.
# Nameless가 중복 됩니다.
# 콘돔24가 중복 됩니다.
# 세연가 중복 됩니다.
# aeta가 중복 됩니다.
# 춘삼가 중복 됩니다.
# 🥺가 중복 됩니다.
# pig_0가 중복 됩니다.
# 𝑖𝑓 𝑦𝑜𝑢가 중복 됩니다.
# 창가 중복 됩니다.
# 지인능욕방 모집가 중복 됩니다.
# 연가 중복 됩니다.
# 𖠇가 중복 됩니다.
# 히가 중복 됩니다.
# 라이크보가 중복 됩니다.
# 흰가 중복 됩니다.
# 쿵가 중복 됩니다.
# 💙FD수린💙가 중복 됩니다.
# 김승준가 중복 됩니다.
# sex가 중복 됩니다.
# 🐶가 중복 됩니다.
# 운동여왕*가 중복 됩니다.
# ᶜʰᵃᵉ ᴷʸᵘⁿᵍ가 중복 됩니다.
# 카마가 중복 됩니다.
# 블루가 중복 됩니다.
# 호잉가 중복 됩니다.
# 둥사미가 중복 됩니다.
# 민식가 중복 됩니다.
# 이시혁가 중복 됩니다.
# 노예조련사가 중복 됩니다.
# 연가 중복 됩니다.
# 채늑가 중복 됩니다.
# ☁️가 중복 됩니다.
# 예지가 중복 됩니다.
# dndlod가 중복 됩니다.
# ᴶᴬᴶᵁ가 중복 됩니다.
# 🙃가 중복 됩니다.
# 변녀가 중복 됩니다.
# 로남이가 중복 됩니다.
# MD_hahaha가 중복 됩니다.
# 용찬가 중복 됩니다.
# 홍두가 중복 됩니다.
# ?가 중복 됩니다.
# 07변녀가 중복 됩니다.
# ㅇㅅㅇ가 중복 됩니다.
# 폰팅폰섹 060-900-0009 섹시미녀 날씬한몸매 폰섹스 전화방 폰팅폰섹가 중복 됩니다.
# wwww가 중복 됩니다.
# 아헤가오 합성 제작가 중복 됩니다.
# 꽤 생김가 중복 됩니다.
# qq가 중복 됩니다.
# 준준가 중복 됩니다.
# 하늘가 중복 됩니다.
# ひめ가 중복 됩니다.
# qwertyzxcvbnm1357가 중복 됩니다.
# 써니사이드 업🙌가 중복 됩니다.
# 혀기가 중복 됩니다.
# 일루가 중복 됩니다.
# 신선아가 중복 됩니다.
# 🤍가 중복 됩니다.
# 공주가 중복 됩니다.
# MD_케빈가 중복 됩니다.
# CHENG XUAN가 중복 됩니다.
# 𝐴𝑥가 중복 됩니다.
# 🆒가 중복 됩니다.
# 26가 중복 됩니다.
# 년가 중복 됩니다.
# 지율가 중복 됩니다.
# 빡이가 중복 됩니다.
# 민이가 중복 됩니다.
# 하라개가 중복 됩니다.
# 고물상가 중복 됩니다.
# KELLY가 중복 됩니다.
# ⭐️가 중복 됩니다.
# 하연가 중복 됩니다.
# CRY MD가 중복 됩니다.
# 루피가 중복 됩니다.
# 고먐가 중복 됩니다.
# 고딩가 중복 됩니다.
# 권정아가 중복 됩니다.
# 최희원가 중복 됩니다.
# Kong가 중복 됩니다.
# 포피가 중복 됩니다.
# 광주 여자가 중복 됩니다.
# 🔞가 중복 됩니다.
# 띠용가 중복 됩니다.
# 뿌뿌가 중복 됩니다.
# 김`가루가 중복 됩니다.
# 연동규가 중복 됩니다.
# ❤️자영판매 채요니❤️가 중복 됩니다.
# 홍길동가 중복 됩니다.
# 연이가 중복 됩니다.
# ⭐️가 중복 됩니다.
# 리코가 중복 됩니다.
# 세연가 중복 됩니다.
# ㄹㄹㄹ가 중복 됩니다.
# 박한나가 중복 됩니다.
# 니꼬내꽁가 중복 됩니다.
# 여월 | 𝓜𝓸𝓸𝓷가 중복 됩니다.
# 먐미가 중복 됩니다.
# ooiro가 중복 됩니다.
# 안현경가 중복 됩니다.
# 섹스밤19-무료야동/한글자막/모자이크제거가 중복 됩니다.
# 세리가 중복 됩니다.
# 안가 중복 됩니다.
# 나나가 중복 됩니다.
# 하루가 중복 됩니다.
# 🥀가 중복 됩니다.
# 쭈야가 중복 됩니다.
# .가 중복 됩니다.
# 익가 중복 됩니다.
# df가 중복 됩니다.
# 윤가 중복 됩니다.
# 22가 중복 됩니다.
# jongho가 중복 됩니다.
# 안성후가 중복 됩니다.
# 노예남가 중복 됩니다.
# sexual가 중복 됩니다.
# 잭오랜턴가 중복 됩니다.
# 애정결핍가 중복 됩니다.
# 이현가 중복 됩니다.
# 희라가 중복 됩니다.
# Choi가 중복 됩니다.
# 펨돔하은가 중복 됩니다.
# 🐻가 중복 됩니다.
# 🎧가 중복 됩니다.
# 운동여신*가 중복 됩니다.
# dkdk가 중복 됩니다.
# 로이가 중복 됩니다.
# MOON🌙가 중복 됩니다.
# 🌵가 중복 됩니다.
# 김수현가 중복 됩니다.
# 사냥꾼가 중복 됩니다.
# 제 5인격가 중복 됩니다.
# Oevejs가 중복 됩니다.
# 홍이여왕❤ 공지글좀 봐주세요가 중복 됩니다.
# 김 훈가 중복 됩니다.
# 🦖가 중복 됩니다.
# 김민지가 중복 됩니다.
# 🍒가 중복 됩니다.
# 변녀 민아가 중복 됩니다.
# lv.ෆ가 중복 됩니다.
# 안 온가 중복 됩니다.
# 연가 중복 됩니다.
# ひまつぶし가 중복 됩니다.
# 뭉가 중복 됩니다.
# 코코가 중복 됩니다.
# 오공가 중복 됩니다.
# •𝑯𝒚𝒖𝒌•가 중복 됩니다.
# Wmdidhne가 중복 됩니다.
# 한결가 중복 됩니다.
# 뇸뇸가 중복 됩니다.
# 밍밍가 중복 됩니다.
# 엥가 중복 됩니다.
# 시아가 중복 됩니다.
# 123ㄷ가 중복 됩니다.
# 유현가 중복 됩니다.
# 공기가 중복 됩니다.
# 핀돔 루나가 중복 됩니다.
# CD수현가 중복 됩니다.
# 06게이가 중복 됩니다.
# ✌가 중복 됩니다.
# 유나가 중복 됩니다.
# 👀가 중복 됩니다.
# 폰팅❤예지가 중복 됩니다.
# ㅂㄴㅇ가 중복 됩니다.
# 🌗가 중복 됩니다.
# 남자가 중복 됩니다.
# ㅗ가 중복 됩니다.
# 단아가 중복 됩니다.
# MD 훈가 중복 됩니다.
# ✨✨✨가 중복 됩니다.
# 차원운가 중복 됩니다.
# 블랙리스트가 중복 됩니다.
# msw가 중복 됩니다.
# 🥰🥰가 중복 됩니다.
# 루나가 중복 됩니다.
# 🍮가 중복 됩니다.
# 🤍가 중복 됩니다.
# 24체대남가 중복 됩니다.
# 크앙가 중복 됩니다.
# 수가 중복 됩니다.
# 김정민가 중복 됩니다.
# Boss가 중복 됩니다.
# 민소윤가 중복 됩니다.
# 운동여신*가 중복 됩니다.
# 팡가 중복 됩니다.
# 보빨 전용 계정입니당ㅎㅅㅎ가 중복 됩니다.
# S가 중복 됩니다.
# ㅇ.ㅇ가 중복 됩니다.
# 윤민수가 중복 됩니다.
# 성가 중복 됩니다.
# hoa가 중복 됩니다.
# 보예가 중복 됩니다.
# #_𝔽𝕒𝕟𝕔𝕪_가 중복 됩니다.
# 김주주가 중복 됩니다.
# 먐가 중복 됩니다.
# 대구가 중복 됩니다.
# 현가 중복 됩니다.
# 🍒Boom🍒가 중복 됩니다.
# 테디가 중복 됩니다.
# 08변녀가 중복 됩니다.
# wedonttalktogether가 중복 됩니다.
# 감자가 중복 됩니다.
# 보라💟가 중복 됩니다.
# 🖤가 중복 됩니다.
# 짱구가 중복 됩니다.
# 𝒘𝒉𝒚𝒓𝒂𝒏𝒐가 중복 됩니다.
# 화성가 중복 됩니다.
# —가 중복 됩니다.
# free_o가 중복 됩니다.
# gale00_006가 중복 됩니다.
# 수다리가 중복 됩니다.
# ᴅᴇɢʀᴀᴅᴇʀ ғʀᴏᴍ ʜᴇʟʟ가 중복 됩니다.
# 황종하가 중복 됩니다.
# OZ가 중복 됩니다.
# 미들스쿨러가 중복 됩니다.
# .가 중복 됩니다.
# 😞가 중복 됩니다.
# 변녀은채가 중복 됩니다.
# 시안인데 🐶❤️가 중복 됩니다.
# 밍가 중복 됩니다.
# 거친방망이가 중복 됩니다.
# 아린✨가 중복 됩니다.
# 메롱가 중복 됩니다.
# 채연가 중복 됩니다.
# 십팔살가 중복 됩니다.
# xorb가 중복 됩니다.
# ㅏㅏ가 중복 됩니다.
# 코코가 중복 됩니다.
# 현서가 중복 됩니다.
# 지닝가 중복 됩니다.
# 💗가 중복 됩니다.
# 재민가 중복 됩니다.
# 령가 중복 됩니다.
# 🌧가 중복 됩니다.
# yak가 중복 됩니다.
# 눈팅가 중복 됩니다.
# ㄱㅇ가 중복 됩니다.
# 다원가 중복 됩니다.
# 원주에서 자취하는 10대남가 중복 됩니다.
# 한가율가 중복 됩니다.
# 트윗가 중복 됩니다.
# 요시루가 중복 됩니다.
# Hvv(후브)가 중복 됩니다.
# 이뿌닝가 중복 됩니다.
# 백수가 중복 됩니다.
# 일휘가 중복 됩니다.
# 🐶가 중복 됩니다.
# 𝐏𝐨𝐧𝐠가 중복 됩니다.
# 노난가 중복 됩니다.
# Batman가 중복 됩니다.
# DGT가 중복 됩니다.
# 🔥가 중복 됩니다.
# 너랑하고싶다가 중복 됩니다.
# 𝒫𝑒𝒶𝒸𝒽가 중복 됩니다.
# 🦄가 중복 됩니다.
# 안동련가 중복 됩니다.
# 파랑이가 중복 됩니다.
# 신윤지가 중복 됩니다.
# 시로_白가 중복 됩니다.
# 김화동가 중복 됩니다.
# MYNA가 중복 됩니다.
# 😻가 중복 됩니다.
# 다가 중복 됩니다.
# 흽가 중복 됩니다.
# woaini가 중복 됩니다.
# 👩🏻‍💼가 중복 됩니다.
# 🌪҉가 중복 됩니다.
# 출장마사지,콜걸샵,출장만남,애인대행.오피걸가 중복 됩니다.
# ( ✌︎'ω')✌︎가 중복 됩니다.
# 함몰찌찌가 중복 됩니다.
# 고수가 중복 됩니다.
# 폰팅만남❤미향가 중복 됩니다.
# 👉🏻🖤가 중복 됩니다.
# 지수가 중복 됩니다.
# (중딩남)가 중복 됩니다.
# 만두가 중복 됩니다.
# 백구였던것가 중복 됩니다.
# 05왕자가 중복 됩니다.
# Lil Choi가 중복 됩니다.
# kim48095가 중복 됩니다.
# 부산 TOP CLASS 여성전용 무료마사지사 골든핑거 시오후키강사 맛집가 중복 됩니다.
# 100가 중복 됩니다.
# 𝕜𝕚𝕥𝕥𝕪가 중복 됩니다.
# J IN가 중복 됩니다.
# 하윤가 중복 됩니다.
# 순딩이(❄️)가 중복 됩니다.
# dbswl가 중복 됩니다.
# 새로운 인생가 중복 됩니다.
# haru00_666가 중복 됩니다.
# 야옹이가 중복 됩니다.
# 🌈가 중복 됩니다.
# 꼬물이🐛가 중복 됩니다.
# ㄱㅁ가 중복 됩니다.
# 🙂가 중복 됩니다.
# daniel가 중복 됩니다.
# 김우럭가 중복 됩니다.
# 현시가 중복 됩니다.
# 🍎가 중복 됩니다.
# 당근가 중복 됩니다.
# 잇.치가 중복 됩니다.
# 🔞가 중복 됩니다.
# @가 중복 됩니다.
# RL가 중복 됩니다.
# 알바몬 루피가 중복 됩니다.
# 민지가 중복 됩니다.
# p가 중복 됩니다.
# 연예인,지인,bj 능욕해드립니다가 중복 됩니다.
# 🍩가 중복 됩니다.
# 호빵가 중복 됩니다.
# 김민수가 중복 됩니다.
# 동수♡가 중복 됩니다.
# Yuri가 중복 됩니다.
# 인간가 중복 됩니다.
# 홍이가 중복 됩니다.
# 사람가 중복 됩니다.
# ㅇㅇㅇ가 중복 됩니다.
# 🐰가 중복 됩니다.
# 하짐가 중복 됩니다.
# 고수환가 중복 됩니다.
# 서연가 중복 됩니다.
# 변남가 중복 됩니다.
# 후니가 중복 됩니다.
# .가 중복 됩니다.
# .가 중복 됩니다.
# 다이스가 중복 됩니다.
# 𝓒𝓮𝓷𝓽가 중복 됩니다.
# ❤️FDsurin❤️가 중복 됩니다.
# 🤍FDsurin🤍가 중복 됩니다.
# Jason가 중복 됩니다.
# 냥냥펀치가 중복 됩니다.
# IM가 중복 됩니다.
# Zahad가 중복 됩니다.
# 지은가 중복 됩니다.
# 사각형오각형가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 👸🏻가 중복 됩니다.
# 암퇘지조련사가 중복 됩니다.
# 백색소음가 중복 됩니다.
# 바미가 중복 됩니다.
# 블루가 중복 됩니다.
# 폰팅폰섹❤예윤가 중복 됩니다.
# 공감가 중복 됩니다.
# Duy Nguyen가 중복 됩니다.
# 야동가 중복 됩니다.
# 으흠가 중복 됩니다.
# 니니어가 중복 됩니다.
# ..가 중복 됩니다.
# 지니가 중복 됩니다.
# 뿌꾸빵가 중복 됩니다.
# 수가 중복 됩니다.
# 천안가 중복 됩니다.
# 이민지가 중복 됩니다.
# 🎀가 중복 됩니다.
# Massa쥐가 중복 됩니다.
# 변남가 중복 됩니다.
# 파로가 중복 됩니다.
# 하나가 중복 됩니다.
# 김 피 온가 중복 됩니다.
# 댕댕가 중복 됩니다.
# 구르르가 중복 됩니다.
# 공 주가 중복 됩니다.
# 🖤가 중복 됩니다.
# 18가 중복 됩니다.
# 시라가 중복 됩니다.
# 폰섹❤리아가 중복 됩니다.
# 한빈가 중복 됩니다.
# 유가 중복 됩니다.
# .가 중복 됩니다.
# FD 예진😘가 중복 됩니다.
# 고오딩가 중복 됩니다.
# 오투가 중복 됩니다.
# Dracko12가 중복 됩니다.
# CD 태연가 중복 됩니다.
# 변ㄴ은지가 중복 됩니다.
# matthew가 중복 됩니다.
# aaa가 중복 됩니다.
# 자영 사진판매 여니가 중복 됩니다.
# 고딩가 중복 됩니다.
# kim가 중복 됩니다.
# 김민수가 중복 됩니다.
# NAVER가 중복 됩니다.
# SGY가 중복 됩니다.
# ㅊㅈ가 중복 됩니다.
# 토론토 후으은남가 중복 됩니다.
# 댕댕이가 중복 됩니다.
# J가 중복 됩니다.
# 골든가 중복 됩니다.
# 🖤가 중복 됩니다.
# 김준수가 중복 됩니다.
# 😑가 중복 됩니다.
# (੭•̀ᴗ•̀)가 중복 됩니다.
# 후잉가 중복 됩니다.
# 온플❤정이가 중복 됩니다.
# 💕가 중복 됩니다.
# 뇸뇸가 중복 됩니다.
# 우기가 중복 됩니다.
# 또이또이가 중복 됩니다.
# 😵가 중복 됩니다.
# 꼬맹가 중복 됩니다.
# 수아가 중복 됩니다.
# 리 더 덕가 중복 됩니다.
# 왕자가 중복 됩니다.
# angel____030가 중복 됩니다.
# 🧀가 중복 됩니다.
# 밤탱가 중복 됩니다.
# 💫가 중복 됩니다.
# 🦈가 중복 됩니다.
# 이지은가 중복 됩니다.
# 20변녀가 중복 됩니다.
# 융가 중복 됩니다.
# 기로(yau)가 중복 됩니다.
# 운동여왕*가 중복 됩니다.
# MD 환가 중복 됩니다.
# 유익한것만 모아볼게가 중복 됩니다.
# 호로로가 중복 됩니다.
# ㅇ ㅡ ㅇ가 중복 됩니다.
# 🌸🌸가 중복 됩니다.
# 그치가 중복 됩니다.
# 04 남자가 중복 됩니다.
# sbdjs가 중복 됩니다.
# Woody가 중복 됩니다.
# 구경꾼가 중복 됩니다.
# gazuagazua가 중복 됩니다.
# 준쥬가 중복 됩니다.
# .가 중복 됩니다.
# zz가 중복 됩니다.
# 니나노가 중복 됩니다.
# 키다리가 중복 됩니다.
# 현가 중복 됩니다.
# 𝖘𝖎𝖗𝖔𝖍가 중복 됩니다.
# 짱구가 중복 됩니다.
# ☺️가 중복 됩니다.
# 변남가 중복 됩니다.
# 😶가 중복 됩니다.
# jon가 중복 됩니다.
# J.J가 중복 됩니다.
# 대물가 중복 됩니다.
# 지은가 중복 됩니다.
# 유가 중복 됩니다.
# SIRI가 중복 됩니다.
# ㅇㅅㅇ가 중복 됩니다.
# 하자가 중복 됩니다.
# 사람가 중복 됩니다.
# 여름가 중복 됩니다.
# 히히가 중복 됩니다.
# 이윤하가 중복 됩니다.
# jjjjj가 중복 됩니다.
# 지민가 중복 됩니다.
# 18남가 중복 됩니다.
# 김바보가 중복 됩니다.
# 벼리 ⭐️가 중복 됩니다.
# 17가 중복 됩니다.
# 입던스타킹,팬티가 중복 됩니다.
# ion가 중복 됩니다.
# 운동여신*가 중복 됩니다.
# 04유빈가 중복 됩니다.
# 원준가 중복 됩니다.
# 오이응가 중복 됩니다.
# 나도가 중복 됩니다.
# 서은가 중복 됩니다.
# 나야가 중복 됩니다.
# 광대가 중복 됩니다.
# Fd.루디아❤️가 중복 됩니다.
# 서울18남가 중복 됩니다.
# 04가 중복 됩니다.
# Ja가 중복 됩니다.
# 김강록가 중복 됩니다.
# 영등포 유부 제임스가 중복 됩니다.
# .가 중복 됩니다.
# Stick가 중복 됩니다.
# pi가 중복 됩니다.
# 박 토 끼가 중복 됩니다.
# mintol가 중복 됩니다.
# 수연가 중복 됩니다.
# 𝑆𝑇𝐴𝑅𝑅𝑌 𝑁𝐼𝐺𝐻𝑇가 중복 됩니다.
# 바다가 중복 됩니다.
# ㅇ가 중복 됩니다.
# kim가 중복 됩니다.
# kevin가 중복 됩니다.
# Drug가 중복 됩니다.
# 현가 중복 됩니다.
# ㅅㅅ할사람가 중복 됩니다.
# 미미미미가 중복 됩니다.
# 카페인가 중복 됩니다.
# 날아오르라!!주작이여♥가 중복 됩니다.
# zaszsad가 중복 됩니다.
# HJ가 중복 됩니다.
# 열려덟가 중복 됩니다.
# 05변남가 중복 됩니다.
# 단이가 중복 됩니다.
# 07변남가 중복 됩니다.
# 브라운가 중복 됩니다.
# --가 중복 됩니다.
# 거근남가 중복 됩니다.
# 03sss가 중복 됩니다.
# 기로로가 중복 됩니다.
# 신성호가 중복 됩니다.
# 진우가 중복 됩니다.
# 🧸가 중복 됩니다.
# 김지혁가 중복 됩니다.
# silver🧚‍♀️가 중복 됩니다.
# 우와잉~가 중복 됩니다.
# 🌸꽃 새롬🌸가 중복 됩니다.
# 일반여성*060*300*1010가 중복 됩니다.
# 자몽가 중복 됩니다.
# HW가 중복 됩니다.
# 서경원가 중복 됩니다.
# 해킹가 중복 됩니다.
# 이이이가 중복 됩니다.
# 후니가 중복 됩니다.
# 암퇘지가 중복 됩니다.
# 나날이하루일상가 중복 됩니다.
# 🐣가 중복 됩니다.
# 존잘러의 일탈가 중복 됩니다.
# 페티쉬판매고딩 ❤️가 중복 됩니다.
# 욱가 중복 됩니다.
# KKFUCKK가 중복 됩니다.
# 이원준가 중복 됩니다.
# sunmin가 중복 됩니다.
# 슝슝가 중복 됩니다.
# 꼬북가 중복 됩니다.
# 𝐒𝐏𝐈𝐍𝐀🌹가 중복 됩니다.
# 우진가 중복 됩니다.
# 눌가 중복 됩니다.
# sseeookkjjoo가 중복 됩니다.
# 초코렛가 중복 됩니다.
# 청주 21살가 중복 됩니다.
# 류지영가 중복 됩니다.
# 츄릅가 중복 됩니다.
# BB가 중복 됩니다.
# Nuskin가 중복 됩니다.
# .가 중복 됩니다.
# 꼬부기가 중복 됩니다.
# 낼름가 중복 됩니다.
# 아마네스가 중복 됩니다.
# 🍑SUPER🍑가 중복 됩니다.
# JUDE_가 중복 됩니다.
# 빡돔가 중복 됩니다.
# 공주님가 중복 됩니다.
# 우다이가 중복 됩니다.
# 123456가 중복 됩니다.
# 𝖉𝖎𝖌𝖚𝖊가 중복 됩니다.
# FD윤서가 중복 됩니다.
# dhkdwldud가 중복 됩니다.
# 나니가 중복 됩니다.
# 밍인데 아니야 사실가 중복 됩니다.
# 권병신가 중복 됩니다.
# 👀가 중복 됩니다.
# 도오톨가 중복 됩니다.
# 김가 중복 됩니다.
# 윤이가 중복 됩니다.
# 왕종훈가 중복 됩니다.
# 초대남가 중복 됩니다.
# dddd가 중복 됩니다.
# 안윤아가 중복 됩니다.
# 류보리가 중복 됩니다.
# 남자발가 중복 됩니다.
# 데이가 중복 됩니다.
# 젤리가 중복 됩니다.
# ㅇ가 중복 됩니다.
# 기모띠가 중복 됩니다.
# 시라얌이가 중복 됩니다.
# 심심가 중복 됩니다.
# 지금당장만나가 중복 됩니다.
# paul jackson가 중복 됩니다.
# 남자가 중복 됩니다.
# 섹트가 중복 됩니다.
# 24남자가 중복 됩니다.
# 호야쿤가 중복 됩니다.
# 먓가 중복 됩니다.
# 아가 중복 됩니다.
# 뇽뇽가 중복 됩니다.
# 설하가 중복 됩니다.
# 메가 중복 됩니다.
# 누구나가 중복 됩니다.
# .가 중복 됩니다.
# 구밍가 중복 됩니다.
# 와요가 중복 됩니다.
# DONALD가 중복 됩니다.
# 고딩가 중복 됩니다.
# 몰라가 중복 됩니다.
# 쀍쀍 하앙가 중복 됩니다.
# 윤서가 중복 됩니다.
# jj가 중복 됩니다.
# 태권🥋하영가 중복 됩니다.
# 🧸가 중복 됩니다.
# 고딩가 중복 됩니다.
# 김 자 안가 중복 됩니다.
# 박유빈가 중복 됩니다.
# 17가 중복 됩니다.
# 19_16가 중복 됩니다.
# ㅅ가 중복 됩니다.
# ㅎㅇㅎㅇ가 중복 됩니다.
# 육변기가 중복 됩니다.
# 훈찬가 중복 됩니다.
# poy343가 중복 됩니다.
# 안녀어어엉가 중복 됩니다.
# 어흥가 중복 됩니다.
# oo가 중복 됩니다.
# 이라가 중복 됩니다.
# ren가 중복 됩니다.
# 응큼해가 중복 됩니다.
# ఇ ఇ가 중복 됩니다.
# 한여름의 8월 어느날가 중복 됩니다.
# ♔오 왕 왕♔가 중복 됩니다.
# Kun가 중복 됩니다.
# 김 요 염가 중복 됩니다.
# 밍끄가 중복 됩니다.
# ㅎㅎ가 중복 됩니다.
# 이혁가 중복 됩니다.
# ㅈㅇ가 중복 됩니다.
# 김애쉬가 중복 됩니다.
# 제트가 중복 됩니다.
# ฅ^•ﻌ•^ฅ가 중복 됩니다.
# ㅇ가 중복 됩니다.
# 아린가 중복 됩니다.
# kang yoon가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 水가 중복 됩니다.
# 얀 비가 중복 됩니다.
# 충성충성가 중복 됩니다.
# 뮬가 중복 됩니다.
# 김가 중복 됩니다.
# 15지윤가 중복 됩니다.
# 이범수가 중복 됩니다.
# 🙉가 중복 됩니다.
# 문어가 중복 됩니다.
# 헬븩가 중복 됩니다.
# 조금 더 김숙희가 중복 됩니다.
# 송이가 중복 됩니다.
# ♨️가 중복 됩니다.
# 은도가 중복 됩니다.
# 예가 중복 됩니다.
# 낙화유수가 중복 됩니다.
# 21가 중복 됩니다.
# 19남가 중복 됩니다.
# •_•가 중복 됩니다.
# MD_펨섭조련사가 중복 됩니다.
# FD코코짱가 중복 됩니다.
# 👀가 중복 됩니다.
# qnrP가 중복 됩니다.
# 범가 중복 됩니다.
# A가 중복 됩니다.
# 변준오가 중복 됩니다.
# Henny가 중복 됩니다.
# 광주가 중복 됩니다.
# 김민우가 중복 됩니다.
# ㅇㅅㅇ가 중복 됩니다.
# Princess가 중복 됩니다.
# 안농가 중복 됩니다.
# Apple가 중복 됩니다.
# 👸가 중복 됩니다.
# 가슴좋아가 중복 됩니다.
# boli6776가 중복 됩니다.
# 김세은가 중복 됩니다.
# 민가 중복 됩니다.
# Jeffanie가 중복 됩니다.
# 김초원가 중복 됩니다.
# 레이가 중복 됩니다.
# ㅎㅇ가 중복 됩니다.
# 유아가 중복 됩니다.
# ☁️가 중복 됩니다.
# 팀가 중복 됩니다.
# 🧚가 중복 됩니다.
# Q가 중복 됩니다.
# 루삥뽕가 중복 됩니다.
# 요섹남가 중복 됩니다.
# 안녕가 중복 됩니다.
# MD나단가 중복 됩니다.
# 🥕가 중복 됩니다.
# xx가 중복 됩니다.
# 두 입가 중복 됩니다.
# 갓 뽀 글가 중복 됩니다.
# lilac가 중복 됩니다.
# 하트가 중복 됩니다.
# 후우우가 중복 됩니다.
# 암캐조련가 중복 됩니다.
# 흫가 중복 됩니다.
# 고먐미가 중복 됩니다.
# 문도가 중복 됩니다.
# FD가 중복 됩니다.
# 박대산가 중복 됩니다.
# 김굠댕가 중복 됩니다.
# 김가 중복 됩니다.
# 뀨가 중복 됩니다.
# 05변남가 중복 됩니다.
# 김네모가 중복 됩니다.
# 기다리는 아픔~가 중복 됩니다.
# 😎가 중복 됩니다.
# 박핑퓽가 중복 됩니다.
# hodor가 중복 됩니다.
# _가 중복 됩니다.
# icecream가 중복 됩니다.
# 여트친 진심녀가 중복 됩니다.
# gg가 중복 됩니다.
# 김존잘가 중복 됩니다.
# 눈팅충가 중복 됩니다.
# 츄가 중복 됩니다.
# 뇸가 중복 됩니다.
# 기요미가 중복 됩니다.
# 04가 중복 됩니다.
# 꼬부기가 중복 됩니다.
# 정지원가 중복 됩니다.
# .가 중복 됩니다.
# 묭이가 중복 됩니다.
# 시우가 중복 됩니다.
# 울산31G가 중복 됩니다.
# 십칠가 중복 됩니다.
# 9_9가 중복 됩니다.
# 헬리잌가 중복 됩니다.
# 윤아가 중복 됩니다.
# 시안가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# chillx2가 중복 됩니다.
# Vladimir가 중복 됩니다.
# 현진가 중복 됩니다.
# ღ이초코ღ가 중복 됩니다.
# 동가 중복 됩니다.
# 밤토리🌰가 중복 됩니다.
# Mr가 중복 됩니다.
# 응더가 중복 됩니다.
# 🔪가 중복 됩니다.
# 까꿍가 중복 됩니다.
# 민서가 중복 됩니다.
# 풀영가 중복 됩니다.
# 20살가 중복 됩니다.
# 햄찌가 중복 됩니다.
# Su가 중복 됩니다.
# nam가 중복 됩니다.
# qwer가 중복 됩니다.
# ㅎㅅㅎ가 중복 됩니다.
# 🐰가 중복 됩니다.
# 안녕가 중복 됩니다.
# 윤가 중복 됩니다.
# youngone😊가 중복 됩니다.
# 아나아가 중복 됩니다.
# 글링🦋가 중복 됩니다.
# 동구가 중복 됩니다.
# 시은가 중복 됩니다.
# ⒽⒶⓀⓊ가 중복 됩니다.
# 3n가 중복 됩니다.
# 🌙가 중복 됩니다.
# 김멜로디가 중복 됩니다.
# 0100가 중복 됩니다.
# 물리쳐라어둠가 중복 됩니다.
# 김 스 윗가 중복 됩니다.
# Breeze가 중복 됩니다.
# Judas가 중복 됩니다.
# C.as가 중복 됩니다.
# 니여친가 중복 됩니다.
# ひな가 중복 됩니다.
# G쭉쭉이가 중복 됩니다.
# JoshHuang가 중복 됩니다.
# 머슴가 중복 됩니다.
# 123가 중복 됩니다.
# ^^가 중복 됩니다.
# 우앙 이뻐요가 중복 됩니다.
# ⚜ _🄷🄰_🄸🄽_ ⚜가 중복 됩니다.
# ?가 중복 됩니다.
# ㅇㅅㅇ가 중복 됩니다.
# 👻가 중복 됩니다.
# 부산가 중복 됩니다.
# Hong가 중복 됩니다.
# 이밍고가 중복 됩니다.
# __ryomi__가 중복 됩니다.
# 1가 중복 됩니다.
# 이운가 중복 됩니다.
# 𝘽𝙄𝙉 ✞가 중복 됩니다.
# 활두가 중복 됩니다.
# 13가 중복 됩니다.
# MD/달고나가 중복 됩니다.
# 윤가 중복 됩니다.
# 아니아가 중복 됩니다.
# 위어가 중복 됩니다.
# 지인합성/아헤가오가 중복 됩니다.
# ❦가 중복 됩니다.
# xeny8888가 중복 됩니다.
# y가 중복 됩니다.
# 다미가 중복 됩니다.
# 망고가 중복 됩니다.
# 원샷가 중복 됩니다.
# 예지가 중복 됩니다.
# Kunsoon가 중복 됩니다.
# 자신감이없다.가 중복 됩니다.
# 수잔가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 지은가 중복 됩니다.
# 藤原 蓮가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 민이가 중복 됩니다.
# 궁금해가 중복 됩니다.
# baby.bird.hands가 중복 됩니다.
# 현진가 중복 됩니다.
# 06가 중복 됩니다.
# 크앙가 중복 됩니다.
# 𝗻𝗼𝗺𝗮𝗻𝘂𝗮𝗹가 중복 됩니다.
# 으악가 중복 됩니다.
# Don가 중복 됩니다.
# utr가 중복 됩니다.
# Jamie Fiel가 중복 됩니다.
# 🍓🍓🍓가 중복 됩니다.
# 19가 중복 됩니다.
# 해린가 중복 됩니다.
# 조련사가 중복 됩니다.
# 김한빈가 중복 됩니다.
# OOO가 중복 됩니다.
# 재민가 중복 됩니다.
# 𝓖𝓪𝓡𝓾가 중복 됩니다.
# ㅣ가 중복 됩니다.
# 🐰가 중복 됩니다.
# 🍒다해가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 김주가 중복 됩니다.
# 야단라가 중복 됩니다.
# D가 중복 됩니다.
# 하얀가 중복 됩니다.
# 야한거좋아여가 중복 됩니다.
# 쭈운가 중복 됩니다.
# 모다피가 중복 됩니다.
# 거늬가 중복 됩니다.
# Dd가 중복 됩니다.
# 𝑫𝑎𝑤𝑛가 중복 됩니다.
# 고딩 남자가 중복 됩니다.
# あ가 중복 됩니다.
# 고가 중복 됩니다.
# 고2가 중복 됩니다.
# 이제 19가 중복 됩니다.
# perhaps가 중복 됩니다.
# 絕滅가 중복 됩니다.
# 김해가 중복 됩니다.
# 오프남가 중복 됩니다.
# 루아가 중복 됩니다.
# 냥가 중복 됩니다.
# 김민철가 중복 됩니다.
# 진진가 중복 됩니다.
# s가 중복 됩니다.
# ._.가 중복 됩니다.
# 💕가 중복 됩니다.
# 진🐷가 중복 됩니다.
# 운동여신*가 중복 됩니다.
# (중딩남)가 중복 됩니다.
# 블루가 중복 됩니다.
# S가 중복 됩니다.
# 🤪가 중복 됩니다.
# 열아홉가 중복 됩니다.
# 제하가 중복 됩니다.
# 지예띵가 중복 됩니다.
# 혀니가 중복 됩니다.
# mou가 중복 됩니다.
# ꩓가 중복 됩니다.
# 니애미가 중복 됩니다.
# 뭉뭉가 중복 됩니다.
# 영상가 중복 됩니다.
# 홍길동가 중복 됩니다.
# 𝚋가 중복 됩니다.
# 🦁가 중복 됩니다.
# MJ가 중복 됩니다.
# 훈가 중복 됩니다.
# ㄷㅊ가 중복 됩니다.
# 겨울가 중복 됩니다.
# 서울 여성전용마사지-(무료)가 중복 됩니다.
# ៖디가 중복 됩니다.
# 폰섹녀❤진아가 중복 됩니다.
# kgh02가 중복 됩니다.
# 뀽가 중복 됩니다.
# 시리가 중복 됩니다.
# 21변녀가 중복 됩니다.
# 다운가 중복 됩니다.
# 내가 원하는거 보는곳가 중복 됩니다.
# 🐥가 중복 됩니다.
# 영상 사진 판매가 중복 됩니다.
# tjd9659가 중복 됩니다.
# .가 중복 됩니다.
# tan가 중복 됩니다.
# 도도옹가 중복 됩니다.
# 이지가 중복 됩니다.
# 𝓜𝓸𝓷𝓼𝓽𝓮𝓻𝓑𝓾𝓑𝓾❣️가 중복 됩니다.
# 남사친하고싶다가 중복 됩니다.
# 관전가 중복 됩니다.
# lilac가 중복 됩니다.
# 혀깅가 중복 됩니다.
# .가 중복 됩니다.
# MmmP가 중복 됩니다.
# ..가 중복 됩니다.
# 노예남가 중복 됩니다.
# 쩜가 중복 됩니다.
# 김 뽀 쨕가 중복 됩니다.
# -가 중복 됩니다.
# MAVRK가 중복 됩니다.
# 🌧가 중복 됩니다.
# MS.B.Gay.Kor가 중복 됩니다.
# 굵자가 중복 됩니다.
# 이영균가 중복 됩니다.
# 연지가 중복 됩니다.
# Master.P가 중복 됩니다.
# MASTER가 중복 됩니다.
# ....가 중복 됩니다.
# 💕혜원💕가 중복 됩니다.
# 🔥가 중복 됩니다.
# tv108가 중복 됩니다.
# 🎧가 중복 됩니다.
# ♩♩예빈♩♩가 중복 됩니다.
# 으으가 중복 됩니다.
# 👸가 중복 됩니다.
# ㅇ가 중복 됩니다.
# 현이가 중복 됩니다.
# 벼리가 중복 됩니다.
# 🍒가 중복 됩니다.
# 쏘가 중복 됩니다.
# 마스크마스크마스크코로나코로나코로나가 중복 됩니다.
# 된다가 중복 됩니다.
# .가 중복 됩니다.
# 수호가 중복 됩니다.
# 혜주가 중복 됩니다.
# H가 중복 됩니다.
# 😈가 중복 됩니다.
# 🤔🤔🤔가 중복 됩니다.
# 야노충가 중복 됩니다.
# 암캐 지수가 중복 됩니다.
# 이현가 중복 됩니다.
# 오빠들의 딸감 1호녀 20살 미소 🙂가 중복 됩니다.
# 꾼가 중복 됩니다.
# qwoeip가 중복 됩니다.
# 일반계가 중복 됩니다.
# 입싸지원자가 중복 됩니다.
# !!!가 중복 됩니다.
# 𝙷𝙰𝙺𝚄(ハク)가 중복 됩니다.
# DDragger가 중복 됩니다.
# 뎀가 중복 됩니다.
# 아버.가 중복 됩니다.
# s가 중복 됩니다.
# 뭉탱가 중복 됩니다.
# D가 중복 됩니다.
# ;가 중복 됩니다.
# ㅎㅇ가 중복 됩니다.
# 춘삼가 중복 됩니다.
# s가 중복 됩니다.
# 포옹가 중복 됩니다.
# mung가 중복 됩니다.
# se가 중복 됩니다.
# 🐑가 중복 됩니다.
# ℛ°가 중복 됩니다.
# 미누가 중복 됩니다.
# 도도검가 중복 됩니다.
# 피스가 중복 됩니다.
# z가 중복 됩니다.
# 먀옹가 중복 됩니다.
# 1111가 중복 됩니다.
# 수프리모86가 중복 됩니다.
# 다온이는 분명히 디엠 가려 받는다고 말해따가 중복 됩니다.
# 세 루 킴가 중복 됩니다.
# 코미가 중복 됩니다.
# 먼지가 중복 됩니다.
# 🐧가 중복 됩니다.
# 윤서가 중복 됩니다.
# 파이가 중복 됩니다.
# 민주가 중복 됩니다.
# 테디가 중복 됩니다.
# 재훈가 중복 됩니다.
# 롬가 중복 됩니다.
# dkdk커플가 중복 됩니다.
# 아가 중복 됩니다.
# 조현수가 중복 됩니다.
# 달가 중복 됩니다.
# hu가 중복 됩니다.
# 김요오가 중복 됩니다.
# Yolza가 중복 됩니다.
# 와가 중복 됩니다.
# jcjw가 중복 됩니다.
# 잉가 중복 됩니다.
# 청월가 중복 됩니다.
# 철가 중복 됩니다.
# com01가 중복 됩니다.
# 안마방가 중복 됩니다.
# 서울18남가 중복 됩니다.
# 준준가 중복 됩니다.
# .가 중복 됩니다.
# 우산가 중복 됩니다.
# ㅋ가 중복 됩니다.
# 댕댕이가 중복 됩니다.
# .가 중복 됩니다.
# 김감성가 중복 됩니다.
# 🥺가 중복 됩니다.
# 배고파가 중복 됩니다.
# 웅가 중복 됩니다.
# 연가 중복 됩니다.
# 연이가 중복 됩니다.
# ㅇㅈ가 중복 됩니다.
# ♨️가 중복 됩니다.
# 딩딩가 중복 됩니다.
# 🔞가 중복 됩니다.
# 이수방가 중복 됩니다.
# Rok가 중복 됩니다.
# ㅅㄱㅅㄱㅅ가 중복 됩니다.
# 가은가 중복 됩니다.
# 대구여성전용마사지가 중복 됩니다.
# 미니가 중복 됩니다.
# 김겨울가 중복 됩니다.
# 뉴웨이브시티가 중복 됩니다.
# 정이가 중복 됩니다.
# 🔞가 중복 됩니다.
# 광주가 중복 됩니다.
# 쿠쿠가 중복 됩니다.
# weird가 중복 됩니다.
# florescence🤍가 중복 됩니다.
# 🔞가 중복 됩니다.
# ㅎ가 중복 됩니다.
# 😈가 중복 됩니다.
# 봉뵹뿅가 중복 됩니다.
# ♥흑자지 갱뱅 노예 세라♥가 중복 됩니다.
# 21남자가 중복 됩니다.
# 김가 중복 됩니다.
# 하라가 중복 됩니다.
# ssone가 중복 됩니다.
# .가 중복 됩니다.
# ㅡ가 중복 됩니다.
# 가현쥔님가 중복 됩니다.
# ㅡ가 중복 됩니다.
# 𝓹𝓻𝓲𝓷𝓬𝓮𝓼𝓼가 중복 됩니다.
# 믱가 중복 됩니다.
# laosno가 중복 됩니다.
# Qwerty가 중복 됩니다.
# 김 시 리가 중복 됩니다.
# 연지가 중복 됩니다.
# 일탈리코가 중복 됩니다.
# 🙃가 중복 됩니다.
# 𝓳𝓞𝓨가 중복 됩니다.
# 보라🔆가 중복 됩니다.
# 04가 중복 됩니다.
# 오프녀가 중복 됩니다.
# 주과청자가 중복 됩니다.
# .가 중복 됩니다.
# TOP가 중복 됩니다.
# 나가 중복 됩니다.
# 🍑가 중복 됩니다.
# 𝔇__𝔪𝔞𝔰_𝔗𝔈ℜ가 중복 됩니다.
# 제프가 중복 됩니다.
# 준호가 중복 됩니다.
# Savitar가 중복 됩니다.
# 박현가 중복 됩니다.
# popi가 중복 됩니다.
# 👿가 중복 됩니다.
# Yghiyu가 중복 됩니다.
# ggggggang가 중복 됩니다.
# 아브릴가 중복 됩니다.
# wow가 중복 됩니다.
# 꿀벌가 중복 됩니다.
# 🌷가 중복 됩니다.
# 아헤가오,지능방 운영가 중복 됩니다.
# Kim가 중복 됩니다.
# princess_C가 중복 됩니다.
# 하 늘가 중복 됩니다.
# 야치가 중복 됩니다.
# 하루가 중복 됩니다.
# 으으가 중복 됩니다.
# @kims85가 중복 됩니다.
# 건가 중복 됩니다.
# 변ㄴ 은지뀽가 중복 됩니다.
# 앋피드가 중복 됩니다.
# umi가 중복 됩니다.
# 힘 좋은 젋은피~가 중복 됩니다.
# yk가 중복 됩니다.
# 강가 중복 됩니다.
# 티티가 중복 됩니다.
# 지인 능욕 ㅋㅋ가 중복 됩니다.
# 04가 중복 됩니다.
# 지연가 중복 됩니다.
# 똘아이가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 색연필가 중복 됩니다.
# 비밀가 중복 됩니다.
# 🌖가 중복 됩니다.
# 할거없다가 중복 됩니다.
# 𝔻𝔸ℕ𝔹𝕀가 중복 됩니다.
# 한해정가 중복 됩니다.
# 김 단가 중복 됩니다.
# 좋아해가 중복 됩니다.
# 유나가 중복 됩니다.
# 김 멍 멍가 중복 됩니다.
# 먕가 중복 됩니다.
# ..가 중복 됩니다.
# 04가 중복 됩니다.
# x가 중복 됩니다.
# 김땡가 중복 됩니다.
# 지 은 탁 ( 소개랑 메인 읽고 디엠하세요 )가 중복 됩니다.
# .가 중복 됩니다.
# 아다🙈🙈가 중복 됩니다.
# 둥이가 중복 됩니다.
# chae.on가 중복 됩니다.
# 🌈가 중복 됩니다.
# 04가 중복 됩니다.
# 미니가 중복 됩니다.
# .가 중복 됩니다.
# 아아아아가 중복 됩니다.
# 박씨가 중복 됩니다.
# 으으으가 중복 됩니다.
# godmundeok가 중복 됩니다.
# D가 중복 됩니다.
# brave가 중복 됩니다.
# 이지가 중복 됩니다.
# 하루살이가 중복 됩니다.
# 짹짹가 중복 됩니다.
# 현가 중복 됩니다.
# dldydxo가 중복 됩니다.
# 하늘가 중복 됩니다.
# 니여친가 중복 됩니다.
# 김시윤가 중복 됩니다.
# 변남가 중복 됩니다.
# 🖤가 중복 됩니다.
# 👻가 중복 됩니다.
# 준가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 겨울가 중복 됩니다.
# 푸가 중복 됩니다.
# 유상욱가 중복 됩니다.
# 엑가 중복 됩니다.
# Win! Leadership Based Interviews-Sports Headlines가 중복 됩니다.
# ㄷㄱㄹ가 중복 됩니다.
# 🐰가 중복 됩니다.
# .가 중복 됩니다.
# 황동준가 중복 됩니다.
# 모히닝가 중복 됩니다.
# Alphine가 중복 됩니다.
# 훈가 중복 됩니다.
# 青 春가 중복 됩니다.
# 댕댕구가 중복 됩니다.
# ♡가 중복 됩니다.
# .가 중복 됩니다.
# 🖤𝐅𝐔𝐂𝐊🖤님의 개 쿠키가 중복 됩니다.
# louis가 중복 됩니다.
# 어좁멸치노잼찐따아다가 중복 됩니다.
# 🐶가 중복 됩니다.
# 안산24가 중복 됩니다.
# 비나가 중복 됩니다.
# 🍒언 니가 중복 됩니다.
# 냥가 중복 됩니다.
# mmmm가 중복 됩니다.
# 김해 조련남_19가 중복 됩니다.
# サブ - 千가 중복 됩니다.
# 동동이가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# .가 중복 됩니다.
# D가 중복 됩니다.
# R_othy가 중복 됩니다.
# .가 중복 됩니다.
# 준우가 중복 됩니다.
# 미르🌙가 중복 됩니다.
# ᓚᘏᗢ ᗦ↞◃가 중복 됩니다.
# 변태가 중복 됩니다.
# 이지가 중복 됩니다.
# 네일가 중복 됩니다.
# Jason가 중복 됩니다.
# 도ㅓ뉴냐가 중복 됩니다.
# 𝔾𝕠𝕝𝕕🥀가 중복 됩니다.
# 벗자벗자가 중복 됩니다.
# ෆ가 중복 됩니다.
# ᆢ가 중복 됩니다.
# (๑･̑◡･̑๑)가 중복 됩니다.
# 뭉가 중복 됩니다.
# 호빵가 중복 됩니다.
# 핀돔 루나가 중복 됩니다.
# 렌가 중복 됩니다.
# 아먀두가 중복 됩니다.
# Boody🦄가 중복 됩니다.
# 괴도키드가 중복 됩니다.
# 김 단가 중복 됩니다.
# 민혁가 중복 됩니다.
# 콘푸로스트가 중복 됩니다.
# mamamgo가 중복 됩니다.
# D가 중복 됩니다.
# 김다윗가 중복 됩니다.
# 愛가 중복 됩니다.
# 🐰가 중복 됩니다.
# 뿜뿌가 중복 됩니다.
# 한소루가 중복 됩니다.
# 먕먕가 중복 됩니다.
# 두두가 중복 됩니다.
# ᴘᴏᴘᴏ가 중복 됩니다.
# 우 루 후 쾅 황가 중복 됩니다.
# 19가 중복 됩니다.
# .가 중복 됩니다.
# 문가 중복 됩니다.
# H가 중복 됩니다.
# 운동여신*가 중복 됩니다.
# 🦋가 중복 됩니다.
# 준가 중복 됩니다.
# 몽글가 중복 됩니다.
# 김태민가 중복 됩니다.
# 🤍가 중복 됩니다.
# 잉가 중복 됩니다.
# T가 중복 됩니다.
# 콩순이가 중복 됩니다.
# 혬가 중복 됩니다.
# 루코가 중복 됩니다.
# 또리가 중복 됩니다.
# 🖤🤍가 중복 됩니다.
# T가 중복 됩니다.
# mini가 중복 됩니다.
# 라인qqww3 일탈 폰섹 마요 프로필확인필수🧚‍♀️가 중복 됩니다.
# coco가 중복 됩니다.
# 🌙가 중복 됩니다.
# CCMA가 중복 됩니다.
# Steven Kim가 중복 됩니다.
# 믱가 중복 됩니다.
# ᴍɪᴜ가 중복 됩니다.
# 밈가 중복 됩니다.
# 그릉가 중복 됩니다.
# 밀양가 중복 됩니다.
# 💖가 중복 됩니다.
# 악마 (암캐 조련사)가 중복 됩니다.
# 아하가 중복 됩니다.
# 쿠쿠까까가 중복 됩니다.
# d가 중복 됩니다.
# 💗가 중복 됩니다.
# 쭈니가 중복 됩니다.
# 🐻가 중복 됩니다.
# 웅가 중복 됩니다.
# 누구게가 중복 됩니다.
# 18고 😝가 중복 됩니다.
# 👹가 중복 됩니다.
# FD. J_min가 중복 됩니다.
# 안녕가 중복 됩니다.
# Min가 중복 됩니다.
# ㅇㅇㅇ가 중복 됩니다.
# 네임가 중복 됩니다.
# Kiro가 중복 됩니다.
# ㆍ가 중복 됩니다.
# 수가 중복 됩니다.
# 머랭가 중복 됩니다.
# 뀨가 중복 됩니다.
# 🌊daddy파파🌊(xn,175,68/경기,서울)가 중복 됩니다.
# 김히죽가 중복 됩니다.
# Min가 중복 됩니다.
# 제이가 중복 됩니다.
# 얌❤️가 중복 됩니다.
# 김수팔가 중복 됩니다.
# 이름을 추가하세요.가 중복 됩니다.
# 뿌뿌가 중복 됩니다.
# 김진구가 중복 됩니다.
# 17살가 중복 됩니다.
# 유나가 중복 됩니다.
# 바랑이가 중복 됩니다.
# 유디트가 중복 됩니다.
# 지효니가 중복 됩니다.
# ㅋㅋ가 중복 됩니다.
# 하늘가 중복 됩니다.
# 몰랑가 중복 됩니다.
# 놀자가 중복 됩니다.
# 고래가 중복 됩니다.
# ㅡ.ㅡ가 중복 됩니다.
# 안녕가 중복 됩니다.
# 민우가 중복 됩니다.
# 오빠들의 딸감 1호 스무살 미소 🙂가 중복 됩니다.
# 범가 중복 됩니다.
# 하으읏가 중복 됩니다.
# 🥰가 중복 됩니다.
# ❤️가 중복 됩니다.
# ?가 중복 됩니다.
# 수원가 중복 됩니다.
# 주인가 중복 됩니다.
# 진이가 중복 됩니다.
# Zmzz가 중복 됩니다.
# 지연가 중복 됩니다.
# 서울 19 MS가 중복 됩니다.
# 운동여왕*가 중복 됩니다.
# ㅓㅑㅈ가 중복 됩니다.
# DA가 중복 됩니다.
# da가 중복 됩니다.
# 코드부부가 중복 됩니다.
# 𝔽𝔻 𝕁𝕦𝕝𝕚𝕒가 중복 됩니다.
# {금ㄸ:144일째} 카뭉이가 중복 됩니다.
# 쁘가 중복 됩니다.
# 늑대가 중복 됩니다.
# 한경환가 중복 됩니다.
# 안가 중복 됩니다.
# 저음가 중복 됩니다.
# 준이가 중복 됩니다.
# 화원🌻가 중복 됩니다.
# davidmorry가 중복 됩니다.
# 코인비트가 중복 됩니다.
# 0가 중복 됩니다.
# 준혁가 중복 됩니다.
# 니남친가 중복 됩니다.
# 난 귀여워가 중복 됩니다.
# angel sosa가 중복 됩니다.
# -ˋˏ ♡ ˎˊ-가 중복 됩니다.
# .가 중복 됩니다.
# ms마루가 중복 됩니다.
# 최강요원가 중복 됩니다.
# 지노가 중복 됩니다.
# 유유가 중복 됩니다.
# 안뇽가 중복 됩니다.
# 김루리😳가 중복 됩니다.
# ㅈㅇㅅ가 중복 됩니다.
# musoyu가 중복 됩니다.
# Loi가 중복 됩니다.
# 娥 淚가 중복 됩니다.
# 이언가 중복 됩니다.
# kim가 중복 됩니다.
# 후장이좋아요가 중복 됩니다.
# 하랑가 중복 됩니다.
# Master.P가 중복 됩니다.
# 고래🐳가 중복 됩니다.
# .가 중복 됩니다.
# 굳나잇MS가 중복 됩니다.
# ₍˄·͈༝·͈˄₎◞ ̑̑ෆ⃛가 중복 됩니다.
# hellovoice9가 중복 됩니다.
# 대전 뭉멍이 고딩가 중복 됩니다.
# ひめ가 중복 됩니다.
# 03변남가 중복 됩니다.
# 주가 중복 됩니다.
# ㅇㅇㅇ가 중복 됩니다.
# 고딩가 중복 됩니다.
# 49&242S 🍑 my baby 🍑가 중복 됩니다.
# 수원가 중복 됩니다.
# 보라가 중복 됩니다.
# 주가 중복 됩니다.
# ReDDi가 중복 됩니다.
# 야동 공유가 중복 됩니다.
# kkkkkk가 중복 됩니다.
# 전지커플 21/22🙈🙉가 중복 됩니다.
# 고딩가 중복 됩니다.
# ♥︎가 중복 됩니다.
# 뇸뇸가 중복 됩니다.
# ㅇ가 중복 됩니다.
# 김 훈가 중복 됩니다.
# 먕먕가 중복 됩니다.
# 호로로로오로오ㅗㅇ가 중복 됩니다.
# ღ͈̮ Seo가 중복 됩니다.
# 빵이좋아가 중복 됩니다.
# 하루가 중복 됩니다.
# 폰섹❤성희가 중복 됩니다.
# 22가 중복 됩니다.
# 안녕가 중복 됩니다.
# MD_Puppy가 중복 됩니다.
# 강철톤가 중복 됩니다.
# 대구가 중복 됩니다.
# 청주가 중복 됩니다.
# 빈가 중복 됩니다.
# 👻가 중복 됩니다.
# 십팔살가 중복 됩니다.
# 각원가 중복 됩니다.
# 공주.가 중복 됩니다.
# Lee가 중복 됩니다.
# 혜은가 중복 됩니다.
# 🌊가 중복 됩니다.
# 김하쿠가 중복 됩니다.
# 만가 중복 됩니다.
# He가 중복 됩니다.
# 변남가 중복 됩니다.
# 비밀가 중복 됩니다.
# 인가 중복 됩니다.
# 현지가 중복 됩니다.
# 부산 성감마사지가 중복 됩니다.
# 후니가 중복 됩니다.
# 사자가 중복 됩니다.
# 고연가 중복 됩니다.
# 지원가 중복 됩니다.
# 엘옹가 중복 됩니다.
# 돔가 중복 됩니다.
# 율가 중복 됩니다.
# 히힣가 중복 됩니다.
# 섭가 중복 됩니다.
# 수아😀가 중복 됩니다.
# 후후가 중복 됩니다.
# 최뻥ㄴㅣ가 중복 됩니다.
# aj가 중복 됩니다.
# 빠셍가 중복 됩니다.
# 삼 신던스타킹.양말.구두.운동화 여자만「서울경기권 직거래」가 중복 됩니다.
# 🤐가 중복 됩니다.
# 자포훈가 중복 됩니다.
# 강동가 중복 됩니다.
# 도희가 중복 됩니다.
# 주현가 중복 됩니다.
# 이러지마가 중복 됩니다.
# 🍑$weet$alt가 중복 됩니다.
# 어흥가 중복 됩니다.
# 희주가 중복 됩니다.
# Fill가 중복 됩니다.
# 🌷가 중복 됩니다.
# 18살인데 인생도 18가 중복 됩니다.
# 한소희가 중복 됩니다.
# 구해요가 중복 됩니다.
# 이다슬가 중복 됩니다.
# 준준🙃💦💦가 중복 됩니다.
# 리코가 중복 됩니다.
# 𝒸𝒽𝒶𝓃가 중복 됩니다.
# 000가 중복 됩니다.
# Hirwit가 중복 됩니다.
# 🐰가 중복 됩니다.
# 고딩암퇘지 나혀닝♥가 중복 됩니다.
# moo0가 중복 됩니다.
# 한가 중복 됩니다.
# 17가 중복 됩니다.
# 대물게이가 중복 됩니다.
# 쩜가 중복 됩니다.
# 자용가 중복 됩니다.
# Moku가 중복 됩니다.
# my__gomi1가 중복 됩니다.
# ?가 중복 됩니다.
# 고딩가 중복 됩니다.
# 부민가 중복 됩니다.
# 잉잉이가 중복 됩니다.
# 🤍가 중복 됩니다.
# cold_cold가 중복 됩니다.
# 𝕕𝕒𝕟𝕞𝕦𝕫𝕚가 중복 됩니다.
# 후니가 중복 됩니다.
# 수연가 중복 됩니다.
# 냠냠가 중복 됩니다.
# 샛 별가 중복 됩니다.
# 나은가 중복 됩니다.
# 아여미가 중복 됩니다.
# 왕자가 중복 됩니다.
# 𝑰_𝒅𝒐𝒏_𝒕_𝒘𝒂𝒏𝒏𝒂_𝒄𝒉𝒊𝒍𝒍_𝒘𝒕_𝑼가 중복 됩니다.
# 🐥가 중복 됩니다.
# JK가 중복 됩니다.
# 하앙가 중복 됩니다.
# 뵹아리🐥가 중복 됩니다.
# 공쥬👑가 중복 됩니다.
# lll가 중복 됩니다.
# Mood€가 중복 됩니다.
# 민서가 중복 됩니다.
# 몽글몽글가 중복 됩니다.
# 루루🧀가 중복 됩니다.
# _가 중복 됩니다.
# Enter가 중복 됩니다.
# 주토커플🐰주디가 중복 됩니다.
# 마산 03가 중복 됩니다.
# 후니가 중복 됩니다.
# holy______가 중복 됩니다.
# 루당가 중복 됩니다.
# 민우가 중복 됩니다.
# ?가 중복 됩니다.
# 🅗🅞🅛🅘🅓🅐🅨가 중복 됩니다.
# 𝑠𝑒𝑜ℎ𝑎가 중복 됩니다.
# 요나💕가 중복 됩니다.
# 하루가 중복 됩니다.
# ☼가 중복 됩니다.
# 🪐가 중복 됩니다.
# CD채연가 중복 됩니다.
# som가 중복 됩니다.
# 운동미인*가 중복 됩니다.
# 체리가 중복 됩니다.
# 택가 중복 됩니다.
# 밈가 중복 됩니다.
# Master.P가 중복 됩니다.
# 𝓑𝓵𝓾𝓮가 중복 됩니다.
# 🌷가 중복 됩니다.
# -가 중복 됩니다.
# ㆍ가 중복 됩니다.
# 로하가 중복 됩니다.
# 민지가 중복 됩니다.
# 🐷가 중복 됩니다.
# 🖤가 중복 됩니다.
# 김루리💗가 중복 됩니다.
# 폰팅 전화데이트 060 501 0800가 중복 됩니다.
# 감자가 중복 됩니다.
# 너의주인님가 중복 됩니다.
# ☁️가 중복 됩니다.
# 오5오가 중복 됩니다.
# 멋이밴놈가 중복 됩니다.
# 수현가 중복 됩니다.
# （╹◡╹）가 중복 됩니다.
# 소리가 중복 됩니다.
# 여춘팔가 중복 됩니다.
# 노예남가 중복 됩니다.
# To가 중복 됩니다.
# 🧡가 중복 됩니다.
# 달가 중복 됩니다.
# 오프남가 중복 됩니다.
# gottafeel가 중복 됩니다.
# 🤐가 중복 됩니다.
# 공주가 중복 됩니다.
# 감자가 중복 됩니다.
# 진성가 중복 됩니다.
# 향이가 중복 됩니다.
# 구름가 중복 됩니다.
# KADA가 중복 됩니다.
# 김민우가 중복 됩니다.
# 대구가 중복 됩니다.
# 경가 중복 됩니다.
# 으앙가 중복 됩니다.
# 밍밍가 중복 됩니다.
# 🙈가 중복 됩니다.
# 𝕀𝕃𝕃𝕌𝕊𝕀𝕆ℕ가 중복 됩니다.
# 재은가 중복 됩니다.
# 04유빈가 중복 됩니다.
# 십일월가 중복 됩니다.
# 토종 고추가루가 중복 됩니다.
# ㅋ가 중복 됩니다.
# 섹가 중복 됩니다.
# Orange가 중복 됩니다.
# 우리가 중복 됩니다.
# 김멍멍가 중복 됩니다.
# 누구게가 중복 됩니다.
# 시은가 중복 됩니다.
# 🌵가 중복 됩니다.
# 16남가 중복 됩니다.
# 🎀꾸리🎀 / 온플 영상 판매중 / 몸매 보장해요 사기 안치니깐 안심하세요 😘가 중복 됩니다.
# 김하율가 중복 됩니다.
# ㅇ.ㅇ가 중복 됩니다.
# .가 중복 됩니다.
# 잉가 중복 됩니다.
# 🌙가 중복 됩니다.
# 뭉이가 중복 됩니다.
# 04가 중복 됩니다.
# 사랑가 중복 됩니다.
# 루아가 중복 됩니다.
# 후니훈가 중복 됩니다.
# 림 몽글 ෆ가 중복 됩니다.
# 19가 중복 됩니다.
# 크롱가 중복 됩니다.
# @___@가 중복 됩니다.
# ⛈가 중복 됩니다.
# _가 중복 됩니다.
# 잉가 중복 됩니다.
# 놎ㅎ가 중복 됩니다.
# someone가 중복 됩니다.
# Canna_ss가 중복 됩니다.
# 이포도🍇가 중복 됩니다.
# 헤헷가 중복 됩니다.
# 🐰가 중복 됩니다.
# 곰탱가 중복 됩니다.
# 율가 중복 됩니다.
# master M가 중복 됩니다.
# 홍연가 중복 됩니다.
# 𝕄oon가 중복 됩니다.
# 김태우가 중복 됩니다.
# 김하늘가 중복 됩니다.
# 민가 중복 됩니다.
# 심심가 중복 됩니다.
# 대구가 중복 됩니다.
# 고2가 중복 됩니다.
# Taehoon.Kim가 중복 됩니다.
# 04가 중복 됩니다.
# 💬가 중복 됩니다.
# 페이가 중복 됩니다.
# ㅇ긔가 중복 됩니다.
# uk가 중복 됩니다.
# 운동여왕*가 중복 됩니다.
# 이윈터가 중복 됩니다.
# Ash가 중복 됩니다.
# SH 😎가 중복 됩니다.
# 예나가 중복 됩니다.
# 🔻꾸리🔺️ / 온플 영상 판매중 / 몸매 보장해요 사기 안치니깐 안심하세요 😘가 중복 됩니다.
# minimalism가 중복 됩니다.
# 민준가 중복 됩니다.
# ㆍ가 중복 됩니다.
# 음가 중복 됩니다.
# 유정이가 중복 됩니다.
# 07변가 중복 됩니다.
# 민서💕가 중복 됩니다.
# 환가 중복 됩니다.
# 찡긋가 중복 됩니다.
# 맛집가 중복 됩니다.
# 🖤FDsurin🖤가 중복 됩니다.
# 자영파는지인이❤️가 중복 됩니다.
# 戀慕之情가 중복 됩니다.
# 선비가 중복 됩니다.
# 핸가 중복 됩니다.
# 힣가 중복 됩니다.
# 하은가 중복 됩니다.
# 𝓚𝓐𝓘가 중복 됩니다.
# 민주가 중복 됩니다.
# ㅡ.ㅡ가 중복 됩니다.
# Ttoose가 중복 됩니다.
# 박준수가 중복 됩니다.
# 블루베리가 중복 됩니다.
# •_•가 중복 됩니다.
# 🎀가 중복 됩니다.
# 04가 중복 됩니다.
# 올15가 중복 됩니다.
# 이선규가 중복 됩니다.
# ғᴏʀ ʏᴏᴜ가 중복 됩니다.
# 정군가 중복 됩니다.
# 맹구가 중복 됩니다.
# ㅇ가 중복 됩니다.
# 렌가 중복 됩니다.
# ㅇㅇ가 중복 됩니다.
# 망망가 중복 됩니다.
# 공쥬가 중복 됩니다.
# 토끼가 중복 됩니다.
# 최가을가 중복 됩니다.
# 소금가 중복 됩니다.
# 수여니가 중복 됩니다.
# 나영가 중복 됩니다.
# 060-300-1111 #리얼폰팅가 중복 됩니다.
# .가 중복 됩니다.
# ㅎ가 중복 됩니다.
# 김준수가 중복 됩니다.
# 쭈가 중복 됩니다.
# 연들🌙가 중복 됩니다.
# 공주가 중복 됩니다.
# 지민가 중복 됩니다.
# 오준석가 중복 됩니다.
# 미린여왕가 중복 됩니다.
# 이지은가 중복 됩니다.
# ㅂㄱ가 중복 됩니다.
# 모가 중복 됩니다.
# 하향가 중복 됩니다.
# 핑크자지가 중복 됩니다.
# 미미가 중복 됩니다.
# .가 중복 됩니다.
# chinol가 중복 됩니다.
# soo가 중복 됩니다.
# 솔아가 중복 됩니다.
# 애벌레가 중복 됩니다.
# 잉잉가 중복 됩니다.
# 𝒜𝓁𝓅𝒽𝒶가 중복 됩니다.
# 𝓱𝓸𝓻𝓷𝔂가 중복 됩니다.
# 구름꽃가 중복 됩니다.
# 기 억💖가 중복 됩니다.
# 혜린가 중복 됩니다.
# 제리가 중복 됩니다.
# Big daddy가 중복 됩니다.
# 🤍가 중복 됩니다.
# 김인간가 중복 됩니다.
# 보라💟가 중복 됩니다.
# 크롱가 중복 됩니다.
# 강원 FD윤서💕가 중복 됩니다.
# Ukkkiii가 중복 됩니다.
# 짱구가 중복 됩니다.
# 놀구용돈주고가 중복 됩니다.
# 조정우가 중복 됩니다.
# ㅎㅇ가 중복 됩니다.
# ㅇ가 중복 됩니다.
# sos가 중복 됩니다.
# 강병관가 중복 됩니다.
# 정현우가 중복 됩니다.
# 이름가 중복 됩니다.
# 💜가 중복 됩니다.
# 봄가 중복 됩니다.
# 06변녀가 중복 됩니다.
# 조재익가 중복 됩니다.
# 김민지가 중복 됩니다.
# FD뮤아가 중복 됩니다.
# 홍이가 중복 됩니다.
# Jamy가 중복 됩니다.
# 꿍가 중복 됩니다.
# -가 중복 됩니다.
# とも가 중복 됩니다.
# 🐯가 중복 됩니다.
# 나비가 중복 됩니다.
# 🌙가 중복 됩니다.
# 빕가 중복 됩니다.
# ^^가 중복 됩니다.
# 찡긋가 중복 됩니다.
# LJ커플가 중복 됩니다.
# 화월 (花月)가 중복 됩니다.
# 중2변남 노포가 중복 됩니다.
# 음조가 중복 됩니다.
# 별빛가 중복 됩니다.
# 봄가 중복 됩니다.
# 고삐리가 중복 됩니다.
# Bruni가 중복 됩니다.
# 사나가 중복 됩니다.
# .가 중복 됩니다.
# 맵고짜고단거가 중복 됩니다.
# .가 중복 됩니다.
# 또또가 중복 됩니다.
# MD가 중복 됩니다.
# 1948

# %%
#트위터 아이디 모음
twitter_id_all = pd.concat([twitter_id1,twitter_id2])
twitter_id_all = twitter_id_all.drop_duplicates(subset=["name"])
twitter_id_all = twitter_id_all.drop(['screen_name','id'], axis=1)
twitter_id_all['IsCrime'] = 1

data  = pd.merge(data,twitter_id_all, on="name", how="left")

data["IsCrime"]=data["IsCrime"].fillna(0)

# %%
hashtag_list = [] #hashtags 딕셔너리에서 꺼냄
hashtag_all = []
for i in data["hashtags"]:
    temp = []
    if len(i) == 0:
        continue
    for j in range(len(i)):
        temp.append(i[j]['text'])
        hashtag_all.append(i[j]['text'])
    hashtag_list.append(temp)

# %%
hashtag_list = pd.Series(hashtag_list)
data["hashtags"] = hashtag_list

# %%
data.loc[data["hashtags"].isnull(),"hashtags"] = ""

# %%
count={} #hashtag의 빈도수
lists = hashtag_all
for i in lists:
    try: count[i] += 1
    except: count[i]=1
count = sorted(count.items(), reverse=True, key=lambda item: item[1])

# %%
count
# Out:
# [('섹트', 111266),
#  ('일탈', 36670),
#  ('오프', 15917),
#  ('고딩', 11194),
#  ('디엠', 8781),
#  ('암캐', 6596),
#  ('자위', 6501),
#  ('펨섭', 5908),
#  ('섹스', 5544),
#  ('변녀', 5381),
#  ('멜돔', 5112),
#  ('건오', 5020),
#  ('일탈계', 4892),
#  ('펨돔', 4641),
#  ('능욕', 4527),
#  ('멜섭', 4363),
#  ('에세머', 3720),
#  ('보지', 3539),
#  ('야노', 3336),
#  ('게이', 3304),
#  ('노예', 3140),
#  ('걸레', 2939),
#  ('중딩', 2910),
#  ('조련', 2706),
#  ('만남', 2535),
#  ('맘눌뎀', 2503),
#  ('육변기', 2434),
#  ('가슴', 2245),
#  ('수치', 2185),
#  ('폰섹', 2161),
#  ('서울', 2153),
#  ('바이', 2063),
#  ('살색계', 2053),
#  ('야동', 2028),
#  ('쓰리썸', 1991),
#  ('비떱', 1964),
#  ('온플', 1906),
#  ('초대남', 1905),
#  ('폰팅', 1882),
#  ('뚱녀', 1876),
#  ('조건', 1864),
#  ('부산', 1806),
#  ('오프녀', 1805),
#  ('영상계', 1798),
#  ('주인님', 1731),
#  ('오프남', 1730),
#  ('수치플', 1729),
#  ('fwb', 1695),
#  ('오컨', 1665),
#  ('자지', 1655),
#  ('대물', 1645),
#  ('일상', 1615),
#  ('신음', 1597),
#  ('스팽', 1592),
#  ('야외노출', 1552),
#  ('애널', 1539),
#  ('갱뱅', 1535),
#  ('자영', 1534),
#  ('암퇘지', 1497),
#  ('섹계', 1469),
#  ('19금', 1362),
#  ('네토', 1347),
#  ('후장', 1337),
#  ('변남', 1319),
#  ('좆물받이', 1303),
#  ('bbw', 1266),
#  ('대구', 1203),
#  ('유부녀', 1195),
#  ('커닐', 1174),
#  ('조건만남', 1156),
#  ('레즈', 1101),
#  ('섹파', 1100),
#  ('보빨', 1077),
#  ('초대', 1074),
#  ('본디지', 1043),
#  ('smer', 1034),
#  ('레즈플', 996),
#  ('트친', 986),
#  ('탑', 981),
#  ('대전', 972),
#  ('시오후키', 965),
#  ('돔', 965),
#  ('얼싸', 932),
#  ('페티쉬', 932),
#  ('스타킹', 922),
#  ('영상', 913),
#  ('빅걸', 903),
#  ('sm', 897),
#  ('350원060폰팅', 872),
#  ('오랄', 862),
#  ('몰카', 859),
#  ('바텀', 827),
#  ('광주', 806),
#  ('노콘', 801),
#  ('디그레이디', 800),
#  ('마사지', 789),
#  ('질싸', 785),
#  ('아다', 780),
#  ('오프만남', 780),
#  ('개보지', 780),
#  ('디그레이더', 775),
#  ('조교', 775),
#  ('애무', 766),
#  ('crossdresser', 766),
#  ('여행', 758),
#  ('펠라', 757),
#  ('라인', 756),
#  ('초대녀', 755),
#  ('음악', 746),
#  ('호텔', 741),
#  ('20대', 741),
#  ('인천', 736),
#  ('친구만들기', 734),
#  ('300원대폰팅', 725),
#  ('발정', 718),
#  ('한국야동', 707),
#  ('BBW', 691),
#  ('경기', 690),
#  ('쉬멜', 688),
#  ('로망트', 682),
#  ('안싸', 682),
#  ('동성', 680),
#  ('핀돔', 674),
#  ('박제', 666),
#  ('육덕', 664),
#  ('커플만남', 658),
#  ('용돈', 656),
#  ('커플', 651),
#  ('구인', 640),
#  ('입싸', 634),
#  ('남자신음', 628),
#  ('야단라', 627),
#  ('FWB', 622),
#  ('팸섭', 621),
#  ('CD', 621),
#  ('부커', 619),
#  ('여장', 615),
#  ('교복', 614),
#  ('팸돔', 593),
#  ('전국폰팅', 588),
#  ('ㅈㄱ', 585),
#  ('시디', 576),
#  ('영통', 545),
#  ('정액', 541),
#  ('ㅈㄱㅁㄴ', 539),
#  ('수원', 533),
#  ('노예녀', 529),
#  ('여장남자', 526),
#  ('엉덩이', 516),
#  ('관전', 509),
#  ('복종', 506),
#  ('여자신음', 505),
#  ('유플', 500),
#  ('주인', 498),
#  ('cd', 491),
#  ('야사', 484),
#  ('트젠', 471),
#  ('meldom', 469),
#  ('분수', 467),
#  ('sissy', 467),
#  ('골든', 464),
#  ('화장실', 463),
#  ('성감마사지', 461),
#  ('섭', 456),
#  ('상납', 454),
#  ('강남', 454),
#  ('전화', 451),
#  ('자위영상', 450),
#  ('애액', 447),
#  ('좆집', 445),
#  ('오르가즘', 445),
#  ('SM', 444),
#  ('사컨', 444),
#  ('맞팔', 440),
#  ('풋잡', 436),
#  ('전화데이트', 434),
#  ('간단', 432),
#  ('입보지', 432),
#  ('대딸', 426),
#  ('자영판매', 424),
#  ('소라넷', 418),
#  ('무료야동', 411),
#  ('살색', 411),
#  ('팔로우', 403),
#  ('일탈남', 401),
#  ('뚱녀성애자', 400),
#  ('스위치', 400),
#  ('스웨디시', 399),
#  ('음란', 398),
#  ('여성전용', 394),
#  ('부천', 394),
#  ('신음소리', 386),
#  ('서울조건', 383),
#  ('스팽커', 383),
#  ('FD', 378),
#  ('350원폰팅', 376),
#  ('전화방', 376),
#  ('여왕', 371),
#  ('마조', 370),
#  ('전남', 367),
#  ('운동', 364),
#  ('오일마사지', 364),
#  ('후빨', 363),
#  ('네토라레', 363),
#  ('노출', 360),
#  ('변태', 355),
#  ('팬티', 353),
#  ('강간', 352),
#  ('경남', 352),
#  ('일탈ㄱㅖ', 351),
#  ('페이만남', 350),
#  ('음란물', 349),
#  ('조건녀', 347),
#  ('정액받이', 345),
#  ('알바', 343),
#  ('군인', 341),
#  ('가축', 339),
#  ('DM', 338),
#  ('30대', 338),
#  ('소프트', 337),
#  ('왁싱', 337),
#  ('풋워십', 337),
#  ('브컨', 332),
#  ('섹스타', 332),
#  ('걸레년', 330),
#  ('일상트', 329),
#  ('콘돔', 327),
#  ('호기심', 327),
#  ('아로마마사지', 327),
#  ('브랫', 326),
#  ('기구플', 325),
#  ('러버', 325),
#  ('여성전용마사지', 324),
#  ('트랜스젠더', 319),
#  ('뒤치기', 319),
#  ('울산', 319),
#  ('dm', 315),
#  ('중국야동', 315),
#  ('헬스', 313),
#  ('여친', 313),
#  ('일탈트', 311),
#  ('무료마사지', 309),
#  ('용돈만남', 306),
#  ('창원', 305),
#  ('스와핑', 301),
#  ('비비떱', 300),
#  ('홍대', 298),
#  ('일탈녀', 297),
#  ('페이', 295),
#  ('토닥이', 289),
#  ('청주', 288),
#  ('섹시', 286),
#  ('리틀', 286),
#  ('펫', 286),
#  ('야설', 284),
#  ('femboy', 284),
#  ('딥쓰롯', 282),
#  ('신림', 280),
#  ('거유', 279),
#  ('대구오프', 279),
#  ('피부관리', 273),
#  ('마음', 270),
#  ('음통', 269),
#  ('스팽키', 269),
#  ('성향', 265),
#  ('성인사진', 265),
#  ('사진공유', 265),
#  ('포르노', 265),
#  ('성인', 263),
#  ('트레이너', 261),
#  ('060폰팅', 261),
#  ('초딩', 260),
#  ('근육', 259),
#  ('부평', 258),
#  ('서울오프', 254),
#  ('gay', 253),
#  ('고민상담', 252),
#  ('국산야동', 251),
#  ('오나홀', 251),
#  ('스핏', 249),
#  ('엑스비디오', 248),
#  ('도그플', 246),
#  ('딜도', 241),
#  ('fd', 241),
#  ('060폰팅350원', 241),
#  ('핀섭', 240),
#  ('대학생', 239),
#  ('후불폰팅', 239),
#  ('ㅇㄹ', 238),
#  ('왁싱남', 238),
#  ('bdsm', 237),
#  ('벗방', 236),
#  ('복근', 236),
#  ('아줌마', 235),
#  ('전주', 235),
#  ('부커만남', 234),
#  ('국내야동', 233),
#  ('BJ', 233),
#  ('신촌', 233),
#  ('스캇', 232),
#  ('diehd', 232),
#  ('인간atm', 231),
#  ('욕플', 231),
#  ('생활관리', 230),
#  ('영상판매', 229),
#  ('몸매', 227),
#  ('펨투펨', 224),
#  ('경북', 222),
#  ('영섹', 221),
#  ('부산오프', 221),
#  ('미션', 221),
#  ('지역폰팅', 219),
#  ('裏アカ女子', 218),
#  ('딥스롯', 218),
#  ('야동넷', 217),
#  ('FETISH', 216),
#  ('제작자영', 215),
#  ('손', 215),
#  ('펨스위치', 214),
#  ('번개', 214),
#  ('천안', 213),
#  ('스폰', 211),
#  ('에스엠', 206),
#  ('slut', 204),
#  ('야한폰팅', 200),
#  ('번호', 200),
#  ('구로', 199),
#  ('부부', 198),
#  ('목소리', 198),
#  ('쓰리섬', 198),
#  ('실시간', 197),
#  ('성향자', 197),
#  ('사카시', 196),
#  ('오너', 196),
#  ('키스', 196),
#  ('여자', 195),
#  ('하드', 194),
#  ('에쎄머', 193),
#  ('폰팅만남', 192),
#  ('디엣', 191),
#  ('하트', 190),
#  ('입던팬티', 189),
#  ('노예남', 187),
#  ('미투', 186),
#  ('폰팅싼곳', 186),
#  ('소통', 185),
#  ('ms', 185),
#  ('horny', 182),
#  ('고딩게이', 182),
#  ('ㅈㅇ', 180),
#  ('사까시', 179),
#  ('cumslut', 175),
#  ('암캐녀', 174),
#  ('여대생', 174),
#  ('야트', 174),
#  ('역삽', 174),
#  ('간단만남', 173),
#  ('일산', 172),
#  ('MD', 172),
#  ('전북', 172),
#  ('페티쉬코리아', 171),
#  ('낙서플', 170),
#  ('060전화번호추천', 170),
#  ('노예년', 168),
#  ('신던스타킹', 167),
#  ('강간플', 165),
#  ('오프영상', 165),
#  ('shemale', 164),
#  ('sex', 164),
#  ('슬림', 164),
#  ('裏アカ男子と繋がりたい', 163),
#  ('광주오프', 163),
#  ('피스팅', 163),
#  ('경북ㅈㄱ', 162),
#  ('프레이', 161),
#  ('전지커플', 161),
#  ('대딩', 159),
#  ('지인', 159),
#  ('여자자위', 159),
#  ('창녀', 156),
#  ('여고딩', 156),
#  ('김해', 155),
#  ('사정', 155),
#  ('변기', 154),
#  ('마산', 154),
#  ('CBT', 153),
#  ('여신', 152),
#  ('bitch', 150),
#  ('안산', 149),
#  ('신던양말', 147),
#  ('트친소', 147),
#  ('선팔', 147),
#  ('충북', 147),
#  ('아헤가오', 146),
#  ('섹시폰팅', 145),
#  ('성인토렌트', 144),
#  ('침', 144),
#  ('돌싱', 143),
#  ('크로스드레서', 142),
#  ('양성', 142),
#  ('원주', 142),
#  ('부부커플', 142),
#  ('BDSM', 141),
#  ('대전오프', 140),
#  ('용인', 140),
#  ('sissy_slut', 140),
#  ('카섹', 139),
#  ('눈섹스', 138),
#  ('발알바', 138),
#  ('정액변기', 137),
#  ('체대생', 137),
#  ('개자지', 137),
#  ('뒷치기', 136),
#  ('심심', 136),
#  ('정삽', 135),
#  ('분당', 135),
#  ('FS', 134),
#  ('여고생', 134),
#  ('훈남', 134),
#  ('근친', 134),
#  ('빨통', 133),
#  ('속옷', 133),
#  ('몸사', 133),
#  ('딸감', 132),
#  ('구속', 131),
#  ('발', 130),
#  ('양성애자', 130),
#  ('드라이브', 129),
#  ('MS', 129),
#  ('연락', 129),
#  ('trap', 129),
#  ('꼬평', 127),
#  ('돌림빵', 126),
#  ('남자', 126),
#  ('일본야동', 125),
#  ('의정부', 124),
#  ('관음증', 124),
#  ('femsub', 124),
#  ('검스', 123),
#  ('담배', 122),
#  ('핑거링', 122),
#  ('슬레이브', 122),
#  ('지갑노예', 121),
#  ('섹', 120),
#  ('파트너', 120),
#  ('직딩', 119),
#  ('친구', 119),
#  ('빅걸성애자', 119),
#  ('멜스위치', 119),
#  ('암캐년', 118),
#  ('콘돔쇼핑몰', 118),
#  ('맬섭', 118),
#  ('NTR', 117),
#  ('자위교육', 116),
#  ('구미', 116),
#  ('경산', 116),
#  ('남고딩', 116),
#  ('패티쉬', 116),
#  ('우울트', 115),
#  ('멍멍이', 115),
#  ('평택', 114),
#  ('중저음', 114),
#  ('맘눌뎸', 114),
#  ('경상도', 113),
#  ('네토리', 113),
#  ('경기도', 113),
#  ('상납금', 113),
#  ('초보', 112),
#  ('일트', 112),
#  ('진주', 111),
#  ('술', 111),
#  ('상황극', 111),
#  ('속박플', 111),
#  ('성인대화', 111),
#  ('지인능욕', 110),
#  ('섹녀', 110),
#  ('노포', 110),
#  ('ahegao', 110),
#  ('충주', 110),
#  ('lover', 109),
#  ('리트윗', 108),
#  ('이태원', 108),
#  ('합성', 107),
#  ('롤', 107),
#  ('통통', 107),
#  ('풀업시디', 107),
#  ('손알바', 107),
#  ('건전', 107),
#  ('발기', 106),
#  ('유부', 106),
#  ('코스프레', 106),
#  ('오카', 106),
#  ('연애', 106),
#  ('대디', 105),
#  ('부부만남', 105),
#  ('관전알바', 105),
#  ('올', 105),
#  ('구인중', 104),
#  ('제천', 104),
#  ('숫캐', 104),
#  ('팬티판매', 103),
#  ('알몸', 102),
#  ('목줄', 102),
#  ('노견', 102),
#  ('젖', 101),
#  ('오줌', 101),
#  ('임신', 101),
#  ('선불폰팅', 101),
#  ('좆물', 101),
#  ('바이남', 101),
#  ('에세머_트친소', 101),
#  ('네토커플', 101),
#  ('핸드워십', 101),
#  ('ㅅㅅ', 101),
#  ('통장구매', 100),
#  ('진동기', 99),
#  ('fs', 99),
#  ('성고민', 99),
#  ('노팬티', 99),
#  ('호르몬시디', 99),
#  ('부부섭', 98),
#  ('공중변소', 97),
#  ('오피', 97),
#  ('아로마', 97),
#  ('부산게이', 97),
#  ('통장구입', 97),
#  ('통장임대', 97),
#  ('통장삽니다', 97),
#  ('개인통장삽니다', 97),
#  ('통장매입', 97),
#  ('계좌임대', 97),
#  ('서울만남', 96),
#  ('양말', 96),
#  ('험핑', 96),
#  ('일상계', 95),
#  ('대구조건', 95),
#  ('흑인', 95),
#  ('도그', 94),
#  ('성인용품', 94),
#  ('통장팝니다', 94),
#  ('개인통장팝니다', 94),
#  ('통장판매', 94),
#  ('통장거래', 94),
#  ('항문', 93),
#  ('리얼폰팅', 93),
#  ('신음계', 93),
#  ('연디', 92),
#  ('댈구', 92),
#  ('세라복', 92),
#  ('裏アカ男子とつながりたい', 91),
#  ('목포', 91),
#  ('일플', 90),
#  ('근육남', 90),
#  ('젖소', 89),
#  ('부산조건', 89),
#  ('입던속옷', 89),
#  ('기구', 89),
#  ('Gay', 89),
#  ('ㅇㅑ동', 89),
#  ('3p', 89),
#  ('퀴어', 89),
#  ('발냄새', 89),
#  ('영딸', 89),
#  ('야방', 89),
#  ('Twink', 88),
#  ('야한대화', 88),
#  ('자포', 88),
#  ('포항', 88),
#  ('제작', 88),
#  ('남자화장실', 88),
#  ('체대', 87),
#  ('몸싸', 87),
#  ('목까시', 87),
#  ('대출', 87),
#  ('학생', 87),
#  ('여수', 87),
#  ('성남', 87),
#  ('이라마치오', 87),
#  ('미시', 86),
#  ('bbcpregnant', 86),
#  ('운동남', 85),
#  ('사진', 85),
#  ('자취', 85),
#  ('肉便器', 85),
#  ('bbcslut', 85),
#  ('야외', 84),
#  ('야한영상', 84),
#  ('스왑', 84),
#  ('대구섹트', 84),
#  ('남양주', 83),
#  ('08변녀', 83),
#  ('누드', 83),
#  ('精液便器', 83),
#  ('세종', 82),
#  ('새디스트', 82),
#  ('안양', 82),
#  ('06변녀', 81),
#  ('20살', 81),
#  ('핑보', 81),
#  ('유두', 80),
#  ('섹트윗', 80),
#  ('청주멜돔', 80),
#  ('고추', 79),
#  ('뚱뚱', 79),
#  ('카톡', 79),
#  ('단톡', 79),
#  ('00년', 78),
#  ('01년', 78),
#  ('노브라', 78),
#  ('ㄴㅋㅇㅆ', 78),
#  ('남자자위', 78),
#  ('이대일', 78),
#  ('좆', 78),
#  ('bwcslut', 78),
#  ('젖꼭지', 77),
#  ('불금', 77),
#  ('걸레보지', 77),
#  ('가슴성애자', 77),
#  ('중딩게이', 77),
#  ('양산', 77),
#  ('멜투멜', 76),
#  ('헬린이', 76),
#  ('페깅', 76),
#  ('음섹', 75),
#  ('간단조건', 75),
#  ('친목', 74),
#  ('nudes', 74),
#  ('ㄱㄷ', 73),
#  ('ladyboy', 73),
#  ('섹트계', 73),
#  ('md', 73),
#  ('번삽', 73),
#  ('중고딩', 73),
#  ('여공남수', 73),
#  ('옾챗', 72),
#  ('해운대', 72),
#  ('公衆便所', 72),
#  ('에셈', 71),
#  ('인천조건', 71),
#  ('여성상위', 71),
#  ('여자친구', 71),
#  ('트렌스젠더', 70),
#  ('레즈섹스', 70),
#  ('제주', 70),
#  ('봉사', 70),
#  ('당일', 70),
#  ('충남', 69),
#  ('08년생', 69),
#  ('슬렌더', 69),
#  ('개인만남', 69),
#  ('대구일탈', 69),
#  ('고3', 68),
#  ('핸드잡', 68),
#  ('목소리플', 68),
#  ('ㅊㄷㄴ', 68),
#  ('휴가', 68),
#  ('성인만남', 68),
#  ('배달노출', 68),
#  ('플러그', 67),
#  ('지인합성', 67),
#  ('젖탱이', 67),
#  ('男の娘', 67),
#  ('원나잇', 67),
#  ('일탈오프', 67),
#  ('중고속옷', 67),
#  ('맘눌', 67),
#  ('판매', 66),
#  ('슬랜더', 66),
#  ('보짓물', 66),
#  ('밍키넷', 66),
#  ('풀업', 66),
#  ('아직_시험안침', 66),
#  ('아이스작대기', 65),
#  ('뚱', 65),
#  ('야외플', 65),
#  ('싸는걸', 65),
#  ('뒷계', 64),
#  ('19살', 64),
#  ('직찍', 64),
#  ('물소리', 64),
#  ('쿠퍼액', 64),
#  ('강아지', 64),
#  ('여자신음소리', 64),
#  ('스폰만남', 63),
#  ('매너', 63),
#  ('서울조건녀', 63),
#  ('우울', 63),
#  ('협박', 63),
#  ('초박형', 63),
#  ('강서', 63),
#  ('색트', 63),
#  ('경주', 63),
#  ('SEX', 63),
#  ('순천', 62),
#  ('fuck', 62),
#  ('오피스룩', 62),
#  ('중고팬티', 62),
#  ('새벽', 61),
#  ('여왕깨기', 61),
#  ('거즈자위', 61),
#  ('섹친', 61),
#  ('ㄸ', 61),
#  ('트친구함', 61),
#  ('클리', 61),
#  ('미자', 61),
#  ('레깅스', 61),
#  ('자위조련', 61),
#  ('국산영상', 61),
#  ('유출영상', 61),
#  ('젠더', 61),
#  ('텀', 61),
#  ('야동판매', 61),
#  ('캔디', 60),
#  ('22살', 60),
#  ('ㅅㅌ', 60),
#  ('군산', 60),
#  ('체벌', 60),
#  ('army', 60),
#  ('대구조건만남', 60),
#  ('개인', 60),
#  ('헌터', 60),
#  ('19ASMR', 60),
#  ('여트친', 59),
#  ('음패', 59),
#  ('강원', 59),
#  ('비밀보장', 59),
#  ('onlyfans', 59),
#  ('성인영상', 59),
#  ('아마추어', 59),
#  ('야동좌표', 59),
#  ('페니반', 59),
#  ('ntr', 59),
#  ('야한동영상', 59),
#  ('유출사진', 59),
#  ('여주인', 58),
#  ('간단알바', 58),
#  ('아산', 58),
#  ('문의', 58),
#  ('ㅈㅇ영상', 58),
#  ('도용', 58),
#  ('괴롭히기', 58),
#  ('카카오톡', 57),
#  ('노예플', 57),
#  ('진격의거인', 57),
#  ('라이너', 57),
#  ('에렌', 57),
#  ('ㅅㅍ', 57),
#  ('발페티시', 57),
#  ('변', 56),
#  ('성상담', 56),
#  ('이벤트', 56),
#  ('섹ㅅㅡ', 56),
#  ('아이스', 56),
#  ('몬스터부부', 56),
#  ('코스튬', 56),
#  ('찌찌', 56),
#  ('익산', 56),
#  ('운동하는여자', 56),
#  ('작대기', 56),
#  ('게트', 56),
#  ('통화', 55),
#  ('일탈계정', 55),
#  ('메인트윗', 55),
#  ('노원', 55),
#  ('수도권', 55),
#  ('bbw는_사랑', 55),
#  ('40대', 55),
#  ('다크웹', 55),
#  ('매너만남', 54),
#  ('21살', 54),
#  ('장난감', 54),
#  ('출장', 54),
#  ('에널', 54),
#  ('노래', 54),
#  ('걸래', 54),
#  ('마스터', 54),
#  ('극초박형', 54),
#  ('야단톡', 54),
#  ('암캐만', 54),
#  ('19cm대물', 54),
#  ('기본4섹', 54),
#  ('오래볼', 54),
#  ('깊고가득차', 54),
#  ('쉬멜영상', 54),
#  ('촬영', 54),
#  ('조건계', 53),
#  ('야외섹스', 53),
#  ('티팬티', 53),
#  ('네토부부', 53),
#  ('직장인', 53),
#  ('비밀', 53),
#  ('살스', 53),
#  ('伪娘', 53),
#  ('边缘', 53),
#  ('성교육', 53),
#  ('브라', 52),
#  ('면상', 52),
#  ('E컵', 52),
#  ('더티', 52),
#  ('헬창', 52),
#  ('수유', 52),
#  ('살섹계', 52),
#  ('오픈카톡', 52),
#  ('천호', 52),
#  ('일반인', 52),
#  ('청라', 52),
#  ('야노미션', 51),
#  ('강원도', 51),
#  ('형님', 51),
#  ('이반', 51),
#  ('비떱성애자', 51),
#  ('msw', 51),
#  ('질내사정', 51),
#  ('진해', 51),
#  ('대디돔', 51),
#  ('협박플', 50),
#  ('걸레녀', 50),
#  ('좋아요', 50),
#  ('소득증빙', 50),
#  ('게친소', 50),
#  ('섻', 50),
#  ('운동하는남자', 50),
#  ('에스크', 50),
#  ('은평', 50),
#  ('딸딸이', 50),
#  ('게이아님', 50),
#  ('bbconly', 50),
#  ('女装', 50),
#  ('섹속', 49),
#  ('스타킹페티쉬', 49),
#  ('재테크', 49),
#  ('핸플', 49),
#  ('은꼴', 49),
#  ('사디스트', 49),
#  ('13변녀', 49),
#  ('종로', 49),
#  ('대전조건', 49),
#  ('스탠', 49),
#  ('양말판매', 49),
#  ('코로나', 49),
#  ('라스', 49),
#  ('바비톡', 49),
#  ('듀얼넘버매입', 49),
#  ('카톡실계정', 49),
#  ('듀얼넘버', 49),
#  ('유플러스듀얼넘버', 49),
#  ('발번', 49),
#  ('실명인증', 49),
#  ('발번매입', 49),
#  ('업자', 49),
#  ('네이버인증', 49),
#  ('인증매입', 49),
#  ('라스매입', 49),
#  ('야상극', 48),
#  ('폰섹녀', 48),
#  ('강남조건', 48),
#  ('감성트', 48),
#  ('다리', 48),
#  ('부산만남', 48),
#  ('잠실', 48),
#  ('군대', 48),
#  ('하비', 48),
#  ('뚱걸', 48),
#  ('ㅈㄱ만남', 48),
#  ('야톡', 48),
#  ('섹스파트너', 48),
#  ('발가락', 47),
#  ('ㅁㄴ', 47),
#  ('피드', 47),
#  ('빅', 47),
#  ('중년', 47),
#  ('고액금전알바', 47),
#  ('娘炮', 47),
#  ('몸평', 46),
#  ('키알', 46),
#  ('딥슬롯', 46),
#  ('오빠', 46),
#  ('메인트', 46),
#  ('여자만', 46),
#  ('감성', 46),
#  ('cum', 46),
#  ('뚠뚜니', 46),
#  ('출장마사지', 46),
#  ('시오', 46),
#  ('심심해', 46),
#  ('부산섹트', 46),
#  ('시흥', 46),
#  ('고양이', 46),
#  ('여성', 46),
#  ('씹물', 46),
#  ('울산오프', 46),
#  ('불토', 46),
#  ('슴가', 45),
#  ('허벅지', 45),
#  ('bi', 45),
#  ('데이트', 45),
#  ('10대', 45),
#  ('천호조건', 45),
#  ('파워볼', 45),
#  ('지능', 45),
#  ('작대기팝니다', 44),
#  ('혼텔', 44),
#  ('fx모아', 44),
#  ('투잡', 44),
#  ('콘돔24', 44),
#  ('젖통', 44),
#  ('눈섹', 44),
#  ('에즈워십', 44),
#  ('2154커플', 44),
#  ('페티쉬판매', 44),
#  ('비키니', 44),
#  ('사정관리', 44),
#  ('blowjob', 44),
#  ('문의는', 44),
#  ('제보', 44),
#  ('쪽지', 43),
#  ('샤워', 43),
#  ('bisexual', 43),
#  ('신불자', 43),
#  ('당일지급', 43),
#  ('ㅇㄴ', 43),
#  ('연신내', 43),
#  ('주안', 43),
#  ('모텔', 43),
#  ('ㅇㄹ영상', 43),
#  ('도리도리', 42),
#  ('강제', 42),
#  ('애널섹스', 42),
#  ('ㅍㅔㅌㅣ쉬ㅋㅗㄹㅣㅇㅏ', 42),
#  ('영등포', 42),
#  ('역삼', 42),
#  ('자극', 42),
#  ('수원오프', 42),
#  ('호구', 42),
#  ('플파', 42),
#  ('땀냄새', 42),
#  ('아자르', 41),
#  ('상납노예', 41),
#  ('후배위', 41),
#  ('관계', 41),
#  ('로망', 41),
#  ('왕가슴', 41),
#  ('리트윗차단', 41),
#  ('스타킹판매', 41),
#  ('일반인유출', 41),
#  ('상극', 41),
#  ('유니더스', 41),
#  ('오산', 41),
#  ('통화중_뒤치기', 41),
#  ('얼공', 40),
#  ('스트리머', 40),
#  ('개인조건', 40),
#  ('무직자', 40),
#  ('오일', 40),
#  ('빈유', 40),
#  ('포섬', 40),
#  ('노모', 40),
#  ('중학생', 40),
#  ('광대플', 40),
#  ('오토코노코', 40),
#  ('담배댈구', 39),
#  ('대리구매', 39),
#  ('김포', 39),
#  ('뚱녀조건', 39),
#  ('운동부', 39),
#  ('힐링', 39),
#  ('커플교환', 39),
#  ('bj', 39),
#  ('새디', 39),
#  ('플', 39),
#  ('구미오프', 39),
#  ('잠실조건', 39),
#  ('성인동영상', 39),
#  ('수원마사지', 39),
#  ('서울마사지', 39),
#  ('분당마사지', 39),
#  ('blackforwife', 39),
#  ('능욕플', 38),
#  ('트찐', 38),
#  ('룸카페', 38),
#  ('슬근', 38),
#  ('글래머', 38),
#  ('속옷판매', 38),
#  ('입술', 38),
#  ('스릴', 38),
#  ('구산', 38),
#  ('젖빨', 38),
#  ('돈', 38),
#  ('벨의_야한시간', 38),
#  ('몸영', 38),
#  ('일산마사지', 38),
#  ('공육', 38),
#  ('자지평가', 37),
#  ('조건알바', 37),
#  ('ㄱㅇ', 37),
#  ('대화', 37),
#  ('노팬', 37),
#  ('상호관전', 37),
#  ('潮吹き', 37),
#  ('소개', 37),
#  ...]

# %%
stopwords = ["아",
"휴",
"아이구",
"아이쿠",
"아이고",
"어",
"나",
"우리",
"저희",
"따라",
"의해",
"을",
"를",
"에",
"의",
"가",
"으로",
"로",
"에게",
"뿐이다",
"의거하여",
"근거하여",
"입각하여",
"기준으로",
"예하면",
"예를 들면",
"예를 들자면",
"저",
"소인",
"소생",
"저희",
"지말고",
"하지마",
"하지마라",
"다른",
"물론",
"또한",
"그리고",
"비길수 없다",
"해서는 안된다",
"뿐만 아니라",
"만이 아니다",
"만은 아니다",
"막론하고",
"관계없이",
"그치지 않다",
"그러나",
"그런데",
"하지만",
"든간에",
"논하지 않다",
"따지지 않다",
"설사",
"비록",
"더라도",
"아니면",
"만 못하다",
"하는 편이 낫다",
"불문하고",
"향하여",
"향해서",
"향하다",
"쪽으로",
"틈타",
"이용하여",
"타다",
"오르다",
"제외하고",
"이 외에",
"이 밖에",
"하여야",
"비로소",
"한다면 몰라도",
"외에도",
"이곳",
"여기",
"부터",
"기점으로",
"따라서",
"할 생각이다",
"하려고하다",
"이리하여",
"그리하여",
"그렇게 함으로써",
"하지만",
"일때",
"할때",
"앞에서",
"중에서",
"보는데서",
"으로써",
"로써",
"까지",
"해야한다",
"일것이다",
"반드시",
"할줄알다",
"할수있다",
"할수있어",
"임에 틀림없다",
"한다면",
"등",
"등등",
"제",
"겨우",
"단지",
"다만",
"할뿐",
"딩동",
"댕그",
"대해서",
"대하여",
"대하면",
"훨씬",
"얼마나",
"얼마만큼",
"얼마큼",
"남짓",
"여",
"얼마간",
"약간",
"다소",
"좀",
"조금",
"다수",
"몇",
"얼마",
"지만",
"하물며",
"또한",
"그러나",
"그렇지만",
"하지만",
"이외에도",
"대해 말하자면",
"뿐이다",
"다음에",
"반대로",
"반대로 말하자면",
"이와 반대로",
"바꾸어서 말하면",
"바꾸어서 한다면",
"만약",
"그렇지않으면",
"까악",
"툭",
"딱",
"삐걱거리다",
"보드득",
"비걱거리다",
"꽈당",
"응당",
"해야한다",
"에 가서",
"각",
"각각",
"여러분",
"각종",
"각자",
"제각기",
"하도록하다",
"와",
"과",
"그러므로",
"그래서",
"고로",
"한 까닭에",
"하기 때문에",
"거니와",
"이지만",
"대하여",
"관하여",
"관한",
"과연",
"실로",
"아니나다를가",
"생각한대로",
"진짜로",
"한적이있다",
"하곤하였다",
"하",
"하하",
"허허",
"아하",
"거바",
"와",
"오",
"왜",
"어째서",
"무엇때문에",
"어찌",
"하겠는가",
"무슨",
"어디",
"어느곳",
"더군다나",
"하물며",
"더욱이는",
"어느때",
"언제",
"야",
"이봐",
"어이",
"여보시오",
"흐흐",
"흥",
"휴",
"헉헉",
"헐떡헐떡",
"영차",
"여차",
"어기여차",
"끙끙",
"아야",
"앗",
"아야",
"콸콸",
"졸졸",
"좍좍",
"뚝뚝",
"주룩주룩",
"솨",
"우르르",
"그래도",
"또",
"그리고",
"바꾸어말하면",
"바꾸어말하자면",
"혹은",
"혹시",
"답다",
"및",
"그에 따르는",
"때가 되어",
"즉",
"지든지",
"설령",
"가령",
"하더라도",
"할지라도",
"일지라도",
"지든지",
"몇",
"거의",
"하마터면",
"인젠",
"이젠",
"된바에야",
"된이상",
"만큼	어찌됏든",
"그위에",
"게다가",
"점에서 보아",
"비추어 보아",
"고려하면",
"하게될것이다",
"일것이다",
"비교적",
"좀",
"보다더",
"비하면",
"시키다",
"하게하다",
"할만하다",
"의해서",
"연이서",
"이어서",
"잇따라",
"뒤따라",
"뒤이어",
"결국",
"의지하여",
"기대여",
"통하여",
"자마자",
"더욱더",
"불구하고",
"얼마든지",
"마음대로",
"주저하지 않고",
"곧",
"즉시",
"바로",
"당장",
"하자마자",
"밖에 안된다",
"하면된다",
"그래",
"그렇지",
"요컨대",
"다시 말하자면",
"바꿔 말하면",
"즉",
"구체적으로",
"말하자면",
"시작하여",
"시초에",
"이상",
"허",
"헉",
"허걱",
"바와같이",
"해도좋다",
"해도된다",
"게다가",
"더구나",
"하물며",
"와르르",
"팍",
"퍽",
"펄렁",
"동안",
"이래",
"하고있었다",
"이었다",
"에서",
"로부터",
"까지",
"예하면",
"했어요",
"해요",
"함께",
"같이",
"더불어",
"마저",
"마저도",
"양자",
"모두",
"습니다",
"가까스로",
"하려고하다",
"즈음하여",
"다른",
"다른 방면으로",
"해봐요",
"습니까",
"했어요",
"말할것도 없고",
"무릎쓰고",
"개의치않고",
"하는것만 못하다",
"하는것이 낫다",
"매",
"매번",
"들",
"모",
"어느것",
"어느",
"로써",
"갖고말하자면",
"어디",
"어느쪽",
"어느것",
"어느해",
"어느 년도",
"라 해도",
"언젠가",
"어떤것",
"어느것",
"저기",
"저쪽",
"저것",
"그때",
"그럼",
"그러면",
"요만한걸",
"그래",
"그때",
"저것만큼",
"그저",
"이르기까지",
"할 줄 안다",
"할 힘이 있다",
"너",
"너희",
"당신",
"어찌",
"설마",
"차라리",
"할지언정",
"할지라도",
"할망정",
"할지언정",
"구토하다",
"게우다",
"토하다",
"메쓰겁다",
"옆사람",
"퉤",
"쳇",
"의거하여",
"근거하여",
"의해",
"따라",
"힘입어",
"그",
"다음",
"버금",
"두번째로",
"기타",
"첫번째로",
"나머지는",
"그중에서",
"견지에서",
"형식으로 쓰여",
"입장에서",
"위해서",
"단지",
"의해되다",
"하도록시키다",
"뿐만아니라",
"반대로",
"전후",
"전자",
"앞의것",
"잠시",
"잠깐",
"하면서",
"그렇지만",
"다음에",
"그러한즉",
"그런즉",
"남들",
"아무거나",
"어찌하든지",
"같다",
"비슷하다",
"예컨대",
"이럴정도로",
"어떻게",
"만약",
"만일",
"위에서 서술한바와같이",
"인 듯하다",
"하지 않는다면",
"만약에",
"무엇",
"무슨",
"어느",
"어떤",
"아래윗",
"조차",
"한데",
"그럼에도 불구하고",
"여전히",
"심지어",
"까지도",
"조차도",
"하지 않도록",
"않기 위하여",
"때",
"시각",
"무렵",
"시간",
"동안",
"어때",
"어떠한",
"하여금",
"네",
"예",
"우선",
"누구",
"누가 알겠는가",
"아무도",
"줄은모른다",
"줄은 몰랏다",
"하는 김에",
"겸사겸사",
"하는바",
"그런 까닭에",
"한 이유는",
"그러니",
"그러니까",
"때문에",
"그",
"너희",
"그들",
"너희들",
"타인",
"것",
"것들",
"너",
"위하여",
"공동으로",
"동시에",
"하기 위하여",
"어찌하여",
"무엇때문에",
"붕붕",
"윙윙",
"나",
"우리",
"엉엉",
"휘익",
"윙윙",
"오호",
"아하",
"어쨋든",
"만 못하다	하기보다는",
"차라리",
"하는 편이 낫다",
"흐흐",
"놀라다",
"상대적으로 말하자면",
"마치",
"아니라면",
"쉿",
"그렇지 않으면",
"그렇지 않다면",
"안 그러면",
"아니었다면",
"하든지",
"아니면",
"이라면",
"좋아",
"알았어",
"하는것도",
"그만이다",
"어쩔수 없다",
"하나",
"일",
"일반적으로",
"일단",
"한켠으로는",
"오자마자",
"이렇게되면",
"이와같다면",
"전부",
"한마디",
"한항목",
"근거로",
"하기에",
"아울러",
"하지 않도록",
"않기 위해서",
"이르기까지",
"이 되다",
"로 인하여",
"까닭으로",
"이유만으로",
"이로 인하여",
"그래서",
"이 때문에",
"그러므로",
"그런 까닭에",
"알 수 있다",
"결론을 낼 수 있다",
"으로 인하여",
"있다",
"어떤것",
"관계가 있다",
"관련이 있다",
"연관되다",
"어떤것들",
"에 대해",
"이리하여",
"그리하여",
"여부",
"하기보다는",
"하느니",
"하면 할수록",
"운운",
"이러이러하다",
"하구나",
"하도다",
"다시말하면",
"다음으로",
"에 있다",
"에 달려 있다",
"우리",
"우리들",
"오히려",
"하기는한데",
"어떻게",
"어떻해",
"어찌됏어",
"어때",
"어째서",
"본대로",
"자",
"이",
"이쪽",
"여기",
"이것",
"이번",
"이렇게말하자면",
"이런",
"이러한",
"이와 같은",
"요만큼",
"요만한 것",
"얼마 안 되는 것",
"이만큼",
"이 정도의",
"이렇게 많은 것",
"이와 같다",
"이때",
"이렇구나",
"것과 같이",
"끼익",
"삐걱",
"따위",
"와 같은 사람들",
"부류의 사람들",
"왜냐하면",
"중의하나",
"오직",
"오로지",
"에 한하다",
"하기만 하면",
"도착하다",
"까지 미치다",
"도달하다",
"정도에 이르다",
"할 지경이다",
"결과에 이르다",
"관해서는",
"여러분",
"하고 있다",
"한 후",
"혼자",
"자기",
"자기집",
"자신",
"우에 종합한것과같이",
"총적으로 보면",
"총적으로 말하면",
"총적으로",
"대로 하다",
"으로서",
"참",
"그만이다",
"할 따름이다",
"쿵",
"탕탕",
"쾅쾅",
"둥둥",
"봐",
"봐라",
"아이야",
"아니",
"와아",
"응",
"아이",
"참나",
"년",
"월",
"일",
"령",
"영",
"일",
"이",
"삼",
"사",
"오",
"육",
"륙",
"칠",
"팔",
"구",
"이천육",
"이천칠",
"이천팔",
"이천구",
"하나",
"둘",
"셋",
"넷",
"다섯",
"여섯",
"일곱",
"여덟",
"아홉",
"령",
"영",]

# %%
import re
#분산 처리가 필요해
def remove(x):
    return re.sub(pattern="#([0-9a-zA-Zㅏ-ㅠㄱ-ㅎ가-힣]*)|(RT[\s]*)|:|@([0-9a-zA-Zㅏ-ㅠㄱ-ㅎ가-힣_]*)|\n|(https:[a-zA-z/.0-9]*|[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]*)",string=x ,repl="")

data["text"] = data["text"].apply(remove)

# %%
data["text"][:100]
# Out:
# 0     뢰알덥의 많아졋다 많아졌다 하지만 인터넷 트위터 공카 말고는 오프라인으로 와닿는 부...
# 1                      알겠어 민혁아 트위터 아이디 뭐냐니깐 별거안하고 블락만할게
# 2      야 나 트위터 넘 많이 들어온다3달 내로 트위터 들어오면 알티해주신 세분께 기프트...
# 3      나도 트위터 처음 시작할때 되게 조신했음 어느정도엿냐면 퍼블트 하나 올릴때 3분 고민함
# 4      야 나 트위터 넘 많이 들어온다3달 내로 트위터 들어오면 알티해주신 세분께 기프트...
#                             ...
# 95                        암캐들 디엠해 조련해줄께 디엠 할때 자기소개
# 96    07년생이 노예녀구한다 라인걸고 대화안할거면 애초에걸지를 말아라 사람 기분잡치니깐 ...
# 97    해변가에서 발정나서 주인님 자지 빠는 개년 발정난년 디엠이나 라인해         ...
# 98    지인 무료로 합성해드려요❤지인 제보박제해드립니다               문의는 D...
# 99    ❗자기소개 꼭 확인❗❗본계 일탈 팔로워 7000❗❣영섹❣주문영상주문사진❣ 자영❣음성...
# Name: text, Length: 100, dtype: object

# %%
# from autoplotter import run_app #자동 플랏 생성 GUI 이거 좋다

# run_app(data, mode="inline", host="127.0.0.1", port=5000)|

# %%
from keras.preprocessing.text import Tokenizer
tk = Tokenizer()
tk.fit_on_texts(data["text"])

# %%
from keras.preprocessing.sequence import pad_sequences 

all_text = tk.texts_to_sequences(data['text'])
all_pad = pad_sequences(all_text, maxlen=50)
all_pad
# Out:
# array([[     0,      0,      0, ...,    938,   4242,  53516],
#        [     0,      0,      0, ...,  53518,  53519,  53520],
#        [     0,      0,      0, ...,   6027,   9256,   9257],
#        ...,
#        [     0,      0,      0, ...,      0,    523, 165143],
#        [     0,      0,      0, ...,     41,  36828,   6093],
#        [     0,      0,      0, ...,      1,   3536,   1936]])

# %%
all_pad.shape
# Out:
# (125409, 50)

# %%
train = data[:100000]
test = data[100000:]
train_pad = all_pad[:len(train)]
test_pad = all_pad[len(train):]

# %%
from keras import Sequential
from keras.layers import *

model = Sequential() 
model.add(Embedding(len(tk.word_index)+1,output_dim=10,input_length = 50)) #0이 들어가기 떄문에 1을 추가 , 중간에 들어가는 3은 단어들을 구별하는 차원 수를 나타냄
model.add(LSTM(32))
# model.add(Flatten()) #lstm이 대신 기능함 
model.add(Dense(5,activation="softmax"))
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["acc"]) #sparse를 붙이는 이유는 분류임을 알려주기 위해
model.fit(train_pad, train["IsCrime"], epochs=3, batch_size=512)
result = model.predict(test_pad)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 17s 89ms/step - loss: 0.8069 - acc: 0.5768
# Epoch 2/5
# 196/196 [==============================] - 18s 89ms/step - loss: 0.5794 - acc: 0.6932 1s - loss:
# Epoch 3/5
# 196/196 [==============================] - 17s 89ms/step - loss: 0.4422 - acc: 0.8023T
# Epoch 4/5
# 196/196 [==============================] - 17s 89ms/step - loss: 0.3451 - acc: 0.8460
# Epoch 5/5
# 196/196 [==============================] - 17s 89ms/step - loss: 0.2978 - acc: 0.8604 0s - loss: 0.2978 - acc: 0.860

# %%
from sklearn.metrics import accuracy_score
accuracy_score(result.argmax(1),test["IsCrime"])
# Out:
# 0.5878232122476288
